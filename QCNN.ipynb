# %% [markdown]
# QUANTUM CNN MODEL USING SDG OPTIMIZER WITH MOMENTUM=0.9

# %%
import os
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try: # allow memory growth
        for g in gpus:
            tf.config.experimental.set_memory_growth(g, True)
    except Exception as e:
        print("GPU config error:", e)
# Out:
# 2025-10-31 13:19:35.391614: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import precision_recall_fscore_support
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import Callback
import pennylane as qml
import os
import time
import cv2
import csv

# %%
# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# -------------------------
# Configuration (tweak these)
# -------------------------
IMG_SIZE = 64
BATCH_SIZE = 16
N_QUBITS = 4
N_LAYERS = 2
EPOCHS = 30
K_FOLDS = 5
CLASS_NAMES = ['glioma', 'meningioma', 'notumor', 'pituitary']

# Quantum/noise/shots settings
SHOTS = 1000                # Number of circuit samples per forward pass (lower -> more statistical noise)
NOISE_PROB = 0.02           # Depolarizing noise probability (0.0 = no noise, 0.02 = 2% depolarizing)
USE_NOISE = True            # Toggle to enable/disable noise injection


print("="*70)
print("QUANTUM-INSPIRED CNN FOR BRAIN TUMOR CLASSIFICATION (UPDATED)")
print("="*70)
print(f"\nConfiguration:")
print(f"  Image Size: {IMG_SIZE}x{IMG_SIZE}")
print(f"  Quantum Qubits: {N_QUBITS}")
print(f"  Quantum Layers: {N_LAYERS}")
print(f"  K-Folds: {K_FOLDS}")
print(f"  Classes: {CLASS_NAMES}")
print(f"  Shots: {SHOTS}  (fewer shots => higher sampling noise)")
print(f"  Depolarizing Noise Enabled: {USE_NOISE}, Noise prob: {NOISE_PROB}")
print("="*70)
# Out:
# ======================================================================
# QUANTUM-INSPIRED CNN FOR BRAIN TUMOR CLASSIFICATION (UPDATED)
# ======================================================================
#
# Configuration:
#   Image Size: 64x64
#   Quantum Qubits: 4
#   Quantum Layers: 2
#   K-Folds: 5
#   Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']
#   Shots: 1000  (fewer shots => higher sampling noise)
#   Depolarizing Noise Enabled: True, Noise prob: 0.02
# ======================================================================

# %%
# -------------------------
# Quantum circuit (with noise)
# -------------------------
def quantum_circuit(inputs, weights):
    """Quantum circuit with data encoding, variational layers and optional depolarizing noise."""
    # Encode classical data into quantum states
    for i in range(N_QUBITS):
        qml.RY(inputs[i], wires=i)

    # Optionally add depolarizing noise after encoding (simulates polarization/depolarizing noise)
    if USE_NOISE and NOISE_PROB > 0:
        for i in range(N_QUBITS):
            qml.DepolarizingChannel(NOISE_PROB, wires=i)

    # Variational quantum layers with entanglement
    for layer in range(N_LAYERS):
        # parameterized single-qubit rotations
        for i in range(N_QUBITS):
            qml.RY(weights[layer, i, 0], wires=i)
            qml.RZ(weights[layer, i, 1], wires=i)

        # entangling CNOT chain
        for i in range(N_QUBITS - 1):
            qml.CNOT(wires=[i, i + 1])
        qml.CNOT(wires=[N_QUBITS - 1, 0])

        # Optionally add depolarizing noise between layers (models decoherence during circuit)
        if USE_NOISE and NOISE_PROB > 0:
            for i in range(N_QUBITS):
                qml.DepolarizingChannel(NOISE_PROB, wires=i)

    # Return expectation values (with finite shots these are estimated)
    return [qml.expval(qml.PauliZ(i)) for i in range(N_QUBITS)]

# %%
try:
    dev = qml.device("default.qubit", wires=N_QUBITS)
    qnode = qml.QNode(quantum_circuit, dev, interface='autograd')
    qnode = qml.transforms.set_shots(SHOTS)(qnode)
except Exception:
    # fallback for older versions
    dev = qml.device("default.qubit", wires=N_QUBITS, shots=SHOTS)
    qnode = qml.QNode(quantum_circuit, dev, interface='autograd')
# Out:
# /mnt/c/Users/hassa/aiml/lib/python3.12/site-packages/pennylane/devices/device_api.py:193: PennyLaneDeprecationWarning: Setting shots on device is deprecated. Please use the `set_shots` transform on the respective QNode instead.
#   warnings.warn(

# %%
# -------------------------
# Quantum-inspired Keras layer (classical differentiable approximation that can call qnode)
# -------------------------
class QuantumInspiredLayer(layers.Layer):
    def __init__(self, n_qubits, n_layers, **kwargs):
        super(QuantumInspiredLayer, self).__init__(**kwargs)
        self.n_qubits = n_qubits
        self.n_layers = n_layers

    def build(self, input_shape):
        self.rotation_weights = self.add_weight(
            name="rotation_weights",
            shape=(self.n_layers, self.n_qubits, 2),
            initializer=keras.initializers.RandomUniform(0, 2*np.pi),
            trainable=True
        )
        self.interaction_weights = self.add_weight(
            name="interaction_weights",
            shape=(self.n_layers, self.n_qubits, self.n_qubits),
            initializer=keras.initializers.GlorotUniform(),
            trainable=True
        )
        super().build(input_shape)

    def call(self, inputs):
        """
        Primary forward pass — classical differentiable transformation inspired by quantum ops.
        Optionally demonstrates true quantum circuit outputs via qnode for small batches.
        """
        x = inputs
        for layer in range(self.n_layers):
            ry_transform = tf.cos(self.rotation_weights[layer, :, 0]) * x + \
                          tf.sin(self.rotation_weights[layer, :, 0]) * tf.roll(x, shift=1, axis=-1)

            rz_transform = tf.cos(self.rotation_weights[layer, :, 1]) * ry_transform - \
                          tf.sin(self.rotation_weights[layer, :, 1]) * tf.roll(ry_transform, shift=-1, axis=-1)

            interaction = tf.matmul(
                tf.expand_dims(rz_transform, axis=-1),
                tf.expand_dims(rz_transform, axis=-2)
            )

            interaction_effect = tf.reduce_sum(
                interaction * self.interaction_weights[layer],
                axis=-1
            )

            x = tf.tanh(rz_transform + 0.1 * interaction_effect)

        # x shape may be (batch, n_qubits) — keep as-is for downstream dense layer
        return x

    def get_config(self):
        config = super().get_config()
        config.update({"n_qubits": self.n_qubits, "n_layers": self.n_layers})
        return config

    def demonstrate_quantum_circuit(self, sample_input):
        """
        Demonstrates the actual quantum circuit output for a small sample input using qnode.
        sample_input: 1D array-like length == n_qubits
        """
        try:
            weights_np = self.rotation_weights.numpy()
            # qnode uses SHOTS configured device and will return sampled expectation values
            result = qnode(sample_input, weights_np)
            return np.array(result)
        except Exception as e:
            print("Quantum demonstration failed:", str(e))
            return None

# %%
# -------------------------
# Model creation (uses QuantumInspiredLayer)
# -------------------------
def create_quantum_cnn_model():
    model = keras.Sequential([
        layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3)),

        # Classical conv blocks
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        layers.Flatten(),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.5),

        # Project to N_QUBITS for the quantum-inspired layer input
        layers.Dense(N_QUBITS, activation='tanh'),

        # Use the defined QuantumInspiredLayer
        QuantumInspiredLayer(N_QUBITS, N_LAYERS, name='quantum_layer'),

        # Output
        layers.Dense(len(CLASS_NAMES), activation='softmax')
    ])
    return model

# %%
# -------------------------
# Data loading
# -------------------------
def load_data(data_dir, img_size=IMG_SIZE):
    images = []
    labels = []
    for idx, class_name in enumerate(CLASS_NAMES):
        class_dir = os.path.join(data_dir, class_name)
        if not os.path.exists(class_dir):
            print(f"Warning: {class_dir} not found, skipping...")
            continue
        print(f"Loading {class_name}...", end=" ")
        count = 0
        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_name)
            try:
                img = cv2.imread(img_path)
                if img is not None:
                    img = cv2.resize(img, (img_size, img_size))
                    img = img / 255.0
                    images.append(img)
                    labels.append(idx)
                    count += 1
            except Exception:
                continue
        print(f"{count} images loaded")
    return np.array(images, dtype=np.float32), np.array(labels, dtype=np.int32)

# %%
# -------------------------
# Grad-CAM and visual functions (unchanged)
# -------------------------
def create_gradcam_heatmap(model, img_array, last_conv_layer_name, pred_index=None):
    grad_model = keras.models.Model(
        [model.inputs],
        [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]
    grads = tape.gradient(class_channel, conv_outputs)
    if grads is None:
        return np.zeros((IMG_SIZE, IMG_SIZE))
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / (tf.math.reduce_max(heatmap) + 1e-10)
    return heatmap.numpy()

def visualize_gradcam(model, test_images, test_labels, save_path='gradcam_results.png'):
    last_conv_layer_name = None
    for layer in reversed(model.layers):
        if isinstance(layer, layers.Conv2D):
            last_conv_layer_name = layer.name
            break
    if last_conv_layer_name is None:
        print("No Conv2D layer found for Grad-CAM")
        return
    n_samples = min(8, len(test_images))
    indices = np.random.choice(len(test_images), n_samples, replace=False)
    fig, axes = plt.subplots(2, n_samples, figsize=(20, 5))
    if n_samples == 1:
        axes = axes.reshape(2, 1)
    for idx, img_idx in enumerate(indices):
        img = test_images[img_idx:img_idx+1]
        true_label = test_labels[img_idx]
        pred = model.predict(img, verbose=0)
        pred_label = np.argmax(pred[0])
        heatmap = create_gradcam_heatmap(model, img, last_conv_layer_name)
        heatmap_resized = cv2.resize(heatmap, (IMG_SIZE, IMG_SIZE))
        axes[0, idx].imshow(img[0])
        axes[0, idx].set_title(f'True: {CLASS_NAMES[true_label]}', fontsize=8)
        axes[0, idx].axis('off')
        axes[1, idx].imshow(img[0])
        axes[1, idx].imshow(heatmap_resized, cmap='jet', alpha=0.5)
        axes[1, idx].set_title(f'Pred: {CLASS_NAMES[pred_label]}', fontsize=8)
        axes[1, idx].axis('off')
    plt.tight_layout()
    plt.savefig(save_path, dpi=150, bbox_inches='tight')
    print(f"\nGrad-CAM visualization saved to {save_path}")
    plt.close()

# %%
def visualize_quantum_layer(model, test_images, save_path='quantum_layer_viz.png'):
    try:
        quantum_model = keras.Model(inputs=model.input, outputs=model.get_layer('quantum_layer').output)
    except Exception:
        print("Quantum layer not found for visualization")
        return
    n_samples = min(4, len(test_images))
    indices = np.random.choice(len(test_images), n_samples, replace=False)
    fig, axes = plt.subplots(n_samples, 2, figsize=(12, 3*n_samples))
    if n_samples == 1:
        axes = axes.reshape(1, 2)
    for idx, img_idx in enumerate(indices):
        img = test_images[img_idx:img_idx+1]
        quantum_output = quantum_model.predict(img, verbose=0)[0]
        axes[idx, 0].imshow(img[0])
        axes[idx, 0].set_title('Input Image', fontsize=10)
        axes[idx, 0].axis('off')
        axes[idx, 1].bar(range(N_QUBITS), quantum_output)
        axes[idx, 1].set_title('Quantum Layer Activations', fontsize=10)
        axes[idx, 1].set_xlabel('Qubit')
        axes[idx, 1].set_ylabel('Activation')
        axes[idx, 1].set_ylim([-1, 1])
        axes[idx, 1].grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(save_path, dpi=150, bbox_inches='tight')
    print(f"Quantum layer visualization saved to {save_path}")
    plt.close()

# %%
def plot_confusion_matrix(y_true, y_pred, save_path='confusion_matrix.png'):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.title('Confusion Matrix - Test Set')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.savefig(save_path, dpi=150, bbox_inches='tight')
    print(f"Confusion matrix saved to {save_path}")
    plt.close()

# %%
def plot_training_history(histories, save_path='training_history.png'):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    for fold_idx, history in enumerate(histories):
        axes[0].plot(history['accuracy'], label=f'Fold {fold_idx+1} Train', alpha=0.6)
        axes[0].plot(history['val_accuracy'], label=f'Fold {fold_idx+1} Val', alpha=0.6, linestyle='--')
    axes[0].set_title('Model Accuracy Across Folds')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
    axes[0].grid(True, alpha=0.3)
    for fold_idx, history in enumerate(histories):
        axes[1].plot(history['loss'], label=f'Fold {fold_idx+1} Train', alpha=0.6)
        axes[1].plot(history['val_loss'], label=f'Fold {fold_idx+1} Val', alpha=0.6, linestyle='--')
    axes[1].set_title('Model Loss Across Folds')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
    axes[1].grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(save_path, dpi=150, bbox_inches='tight')
    print(f"Training history saved to {save_path}")
    plt.close()

# %%
class TimingCallback(Callback):
    def __init__(self, fold_no, epoch_time_records):
        super().__init__()
        self.fold_no = fold_no
        self.epoch_times = []
        self.epoch_time_records = epoch_time_records

    def on_epoch_begin(self, epoch, logs=None):
        self._epoch_start = time.time()

    def on_epoch_end(self, epoch, logs=None):
        t = time.time() - self._epoch_start
        self.epoch_times.append(t)
        # safely extract learning rate (Keras 3 uses .learning_rate)
        try:
            lr = float(tf.keras.backend.get_value(self.model.optimizer.learning_rate))
        except:
            lr = None
        # record: fold, epoch (1-based), time, train_acc, val_acc, train_loss, val_loss, lr
        train_acc = logs.get('accuracy')
        val_acc = logs.get('val_accuracy')
        train_loss = logs.get('loss')
        val_loss = logs.get('val_loss')
        self.epoch_time_records.append([self.fold_no, epoch+1, t, train_acc, val_acc, train_loss, val_loss, lr])
        print(f"⏱️ [Fold {self.fold_no}] Epoch {epoch+1} time: {t:.2f}s | train_acc={train_acc:.4f} val_acc={val_acc:.4f}")

# %%
# -------------------------
# Main training/evaluation pipeline
# -------------------------
from tensorflow.keras.utils import to_categorical

def main():
    train_dir = 'Brain_Tumor_data/Training'
    test_dir = 'Brain_Tumor_data/Testing'

    if not os.path.exists(train_dir):
        print(f"\nError: Training directory '{train_dir}' not found!")
        return

    print("\n" + "="*70)
    print("LOADING DATA")
    print("="*70)
    X_train, y_train = load_data(train_dir)
    y_train = to_categorical(y_train, num_classes=len(CLASS_NAMES))

    print(f"\nTraining data: {X_train.shape}, Labels: {y_train.shape}")

    X_test, y_test = None, None
    if os.path.exists(test_dir):
        X_test, y_test = load_data(test_dir)
        if y_test is not None:
            y_test = to_categorical(y_test, num_classes=len(CLASS_NAMES))


        print(f"Testing data: {X_test.shape}, Labels: {y_test.shape}")
    else:
        print(f"\nWarning: Test directory '{test_dir}' not found. Skipping test evaluation.")

    # K-Fold Cross Validation
    print("\n" + "="*70)
    print("K-FOLD CROSS VALIDATION TRAINING")
    print("="*70)

    kfold = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)
    fold_scores = []
    histories = []
    best_model = None
    best_val_acc = 0.0
    epoch_time_records = []  # collect [fold, epoch, time, train_acc, val_acc, train_loss, val_loss, lr]
    os.makedirs("logs", exist_ok=True)

    for fold, (train_idx, val_idx) in enumerate(kfold.split(X_train)):
        fold_no = fold + 1
        print(f"\n{'='*70}")
        print(f"FOLD {fold_no}/{K_FOLDS}")
        print('='*70)

        X_fold_train, X_fold_val = X_train[train_idx], X_train[val_idx]
        y_fold_train, y_fold_val = y_train[train_idx], y_train[val_idx]
        print(f"Train samples: {len(X_fold_train)}, Val samples: {len(X_fold_val)}")

        model = create_quantum_cnn_model()
        # Compile with SGD(momentum=0.9)
        model.compile(
            optimizer=keras.optimizers.SGD(learning_rate=0.001, momentum=0.9),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )

        callbacks = [
            keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, verbose=1),
            keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, min_lr=1e-7, verbose=1),
        ]

        timing_cb = TimingCallback(fold_no, epoch_time_records)
        callbacks.append(timing_cb)

        fold_start_time = time.time()
        try:
            history = model.fit(
                X_fold_train, y_fold_train,
                validation_data=(X_fold_val, y_fold_val),
                epochs=EPOCHS,
                batch_size=BATCH_SIZE,
                callbacks=callbacks,
                verbose=1
            )
            fold_training_time = time.time() - fold_start_time

            val_loss, val_acc = model.evaluate(X_fold_val, y_fold_val, verbose=0)
            fold_scores.append(val_acc)
            histories.append(history.history)

            print(f"\nFold {fold_no} Results:")
            print(f"  Validation Accuracy: {val_acc:.4f}")
            print(f"  Validation Loss: {val_loss:.4f}")
            print(f"  Fold Training Time: {fold_training_time:.2f} seconds")

            # Save model for this fold
            model.save(f"quantum_cnn_fold{fold_no}.keras")
            print(f"[INFO] Saved fold model: quantum_cnn_fold{fold_no}.keras")

            if val_acc > best_val_acc:
                best_val_acc = val_acc
                best_model = model
                print(f"  *** New best model! ***")

        except Exception as e:
            print(f"\nError in fold {fold_no}: {str(e)}")
            continue

    if len(fold_scores) == 0:
        print("\nNo folds completed successfully.")
        return

    # Save epoch timing CSV
    csv_path = "logs/qcnn_epoch_times.csv"
    with open(csv_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Fold", "Epoch", "TimeSec", "TrainAcc", "ValAcc", "TrainLoss", "ValLoss", "LR"])
        writer.writerows(epoch_time_records)
    print(f"[INFO] Epoch timing data saved to: {csv_path}")

    # Plot epoch times
    if len(epoch_time_records) > 0:
        arr = np.array(epoch_time_records)
        folds_plot = arr[:,0].astype(int)
        epochs_plot = arr[:,1].astype(int)
        times_plot = arr[:,2].astype(float)

        plt.figure(figsize=(10,6))
        sns.lineplot(x=epochs_plot, y=times_plot, hue=folds_plot, marker="o")
        plt.title("Training Time per Epoch across Folds")
        plt.xlabel("Epoch")
        plt.ylabel("Time (seconds)")
        plt.legend(title="Fold", loc="upper left")
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plot_path = "logs/qcnn_epoch_time_plot.png"
        plt.savefig(plot_path)
        plt.show()
        plt.close()
        print(f"[INFO] Epoch time plot saved to: {plot_path}")

    # CV summary
    print("\n" + "="*70)
    print("CROSS-VALIDATION RESULTS")
    print("="*70)
    print(f"Fold Accuracies: {[f'{acc:.4f}' for acc in fold_scores]}")
    print(f"Mean CV Accuracy: {np.mean(fold_scores):.4f} (+/- {np.std(fold_scores):.4f})")
    print(f"Best Fold Accuracy: {max(fold_scores):.4f}")

    # Plot training history
    if len(histories) > 0:
        plot_training_history(histories)

    # Test evaluation using best_model
    if X_test is not None and y_test is not None and best_model is not None:
        print("\n" + "="*70)
        print("TEST SET EVALUATION")
        print("="*70)
        test_loss, test_acc = best_model.evaluate(X_test, y_test, verbose=0)
        print(f"Test Accuracy: {test_acc:.4f}")
        print(f"Test Loss: {test_loss:.4f}")

        y_pred = best_model.predict(X_test, verbose=0)
        y_pred_classes = np.argmax(y_pred, axis=1)
        y_true_classes = np.argmax(y_test, axis=1)

        # Classification report & metrics
        print("\n" + "-"*70)
        print("CLASSIFICATION REPORT")
        print("-"*70)
        print(classification_report(y_true_classes, y_pred_classes, target_names=CLASS_NAMES))
        precision, recall, f1, support = precision_recall_fscore_support(
            y_true_classes, y_pred_classes, average=None, labels=range(len(CLASS_NAMES))
        )
        print("\n" + "-"*70)
        print("PER-CLASS PERFORMANCE ANALYSIS")
        print("-"*70)
        for i, class_name in enumerate(CLASS_NAMES):
            print(f"\n{class_name.upper()}:")
            print(f"  Precision: {precision[i]:.4f}")
            print(f"  Recall:    {recall[i]:.4f}")
            print(f"  F1-Score:  {f1[i]:.4f}")
            print(f"  Support:   {support[i]}")

        # Visualizations
        plot_confusion_matrix(y_true_classes, y_pred_classes)
        # visualize_gradcam(best_model, X_test, y_test)
        visualize_quantum_layer(best_model, X_test)

    # Save best model
    if best_model is not None:
        best_model.save('quantum_cnn_brain_tumor_model.keras')
        print("\n" + "="*70)
        print("Model saved as 'quantum_cnn_brain_tumor_model.keras'")
        print("="*70)

    print("\n✓ Training and evaluation complete!")
    print("\nGenerated files:")
    print("  1. quantum_cnn_brain_tumor_model.keras - Trained best model")
    print("  2. quantum_cnn_fold{n}.keras - Per-fold saved models")
    print("  3. logs/qcnn_epoch_times.csv - Epoch timing & metrics")
    print("  4. logs/qcnn_epoch_time_plot.png - Epoch time plot")
    print("  5. training_history.png - Training curves")
    print("  6. confusion_matrix.png - Confusion matrix")
    print("  7. gradcam_results.png - Grad-CAM visualizations")
    print("  8. quantum_layer_viz.png - Quantum layer activations")

# %%
if __name__ == "__main__":
    main()
# Out:
# ======================================================================
# LOADING DATA
# ======================================================================
# Loading glioma... 1321 images loaded
# Loading meningioma... 1339 images loaded
# Loading notumor... 1595 images loaded
# Loading pituitary... 1457 images loaded
#
# Training data: (5712, 64, 64, 3), Labels: (5712, 4)
# Loading glioma... 300 images loaded
# Loading meningioma... 306 images loaded
# Loading notumor... 405 images loaded
# Loading pituitary... 300 images loaded
# Testing data: (1311, 64, 64, 3), Labels: (1311, 4)
#
# ======================================================================
# K-FOLD CROSS VALIDATION TRAINING
# ======================================================================
#
# ======================================================================
# FOLD 1/5
# ======================================================================
# Train samples: 4569, Val samples: 1143
# Epoch 1/30
# 2025-10-31 13:43:14.568812: I external/local_xla/xla/service/service.cc:163] XLA service 0x26413430 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-31 13:43:14.568869: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 2050, Compute Capability 8.6
# 2025-10-31 13:43:14.825362: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-31 13:43:15.488662: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91300
#   1/286 ━━━━━━━━━━━━━━━━━━━━ 1:06:42 14s/step - accuracy: 0.1875 - loss: 1.5744
# I0000 00:00:1761918206.272773   37855 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3215 - loss: 1.3823⏱️ [Fold 1] Epoch 1 time: 32.21s | train_acc=0.3738 val_acc=0.4033
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 32s 64ms/step - accuracy: 0.3738 - loss: 1.3150 - val_accuracy: 0.4033 - val_loss: 1.5113 - learning_rate: 0.0010
# Epoch 2/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5645 - loss: 1.1688⏱️ [Fold 1] Epoch 2 time: 4.21s | train_acc=0.5872 val_acc=0.6019
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.5872 - loss: 1.1352 - val_accuracy: 0.6019 - val_loss: 1.2181 - learning_rate: 0.0010
# Epoch 3/30
# 219/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6652 - loss: 1.0148⏱️ [Fold 1] Epoch 3 time: 2.17s | train_acc=0.6802 val_acc=0.8005
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6802 - loss: 0.9825 - val_accuracy: 0.8005 - val_loss: 0.8490 - learning_rate: 0.0010
# Epoch 4/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7169 - loss: 0.8903⏱️ [Fold 1] Epoch 4 time: 4.21s | train_acc=0.7223 val_acc=0.7935
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.7223 - loss: 0.8694 - val_accuracy: 0.7935 - val_loss: 0.8032 - learning_rate: 0.0010
# Epoch 5/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7382 - loss: 0.8094⏱️ [Fold 1] Epoch 5 time: 4.32s | train_acc=0.7431 val_acc=0.7944
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.7431 - loss: 0.7923 - val_accuracy: 0.7944 - val_loss: 0.7159 - learning_rate: 0.0010
# Epoch 6/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7524 - loss: 0.7373⏱️ [Fold 1] Epoch 6 time: 4.40s | train_acc=0.7632 val_acc=0.8101
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.7632 - loss: 0.7211 - val_accuracy: 0.8101 - val_loss: 0.6699 - learning_rate: 0.0010
# Epoch 7/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7919 - loss: 0.6686⏱️ [Fold 1] Epoch 7 time: 4.33s | train_acc=0.7901 val_acc=0.8171
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.7901 - loss: 0.6604 - val_accuracy: 0.8171 - val_loss: 0.6298 - learning_rate: 0.0010
# Epoch 8/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7809 - loss: 0.6616⏱️ [Fold 1] Epoch 8 time: 4.24s | train_acc=0.7763 val_acc=0.7857
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.7763 - loss: 0.6637 - val_accuracy: 0.7857 - val_loss: 0.6485 - learning_rate: 0.0010
# Epoch 9/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7921 - loss: 0.6267⏱️ [Fold 1] Epoch 9 time: 4.14s | train_acc=0.7921 val_acc=0.8110
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7921 - loss: 0.6151 - val_accuracy: 0.8110 - val_loss: 0.6012 - learning_rate: 0.0010
# Epoch 10/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7961 - loss: 0.5986⏱️ [Fold 1] Epoch 10 time: 4.21s | train_acc=0.7954 val_acc=0.8023
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.7954 - loss: 0.5985 - val_accuracy: 0.8023 - val_loss: 0.5559 - learning_rate: 0.0010
# Epoch 11/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7895 - loss: 0.6074⏱️ [Fold 1] Epoch 11 time: 2.50s | train_acc=0.8015 val_acc=0.8469
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8015 - loss: 0.5818 - val_accuracy: 0.8469 - val_loss: 0.5157 - learning_rate: 0.0010
# Epoch 12/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8044 - loss: 0.5771⏱️ [Fold 1] Epoch 12 time: 4.27s | train_acc=0.8089 val_acc=0.8574
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8089 - loss: 0.5679 - val_accuracy: 0.8574 - val_loss: 0.4770 - learning_rate: 0.0010
# Epoch 13/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8160 - loss: 0.5386⏱️ [Fold 1] Epoch 13 time: 4.16s | train_acc=0.8188 val_acc=0.8548
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8188 - loss: 0.5293 - val_accuracy: 0.8548 - val_loss: 0.4825 - learning_rate: 0.0010
# Epoch 14/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8245 - loss: 0.5402⏱️ [Fold 1] Epoch 14 time: 4.28s | train_acc=0.8304 val_acc=0.8320
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8304 - loss: 0.5190 - val_accuracy: 0.8320 - val_loss: 0.5116 - learning_rate: 0.0010
# Epoch 15/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8316 - loss: 0.5218⏱️ [Fold 1] Epoch 15 time: 4.23s | train_acc=0.8280 val_acc=0.8241
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8280 - loss: 0.5207 - val_accuracy: 0.8241 - val_loss: 0.5569 - learning_rate: 0.0010
# Epoch 16/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8361 - loss: 0.5017⏱️ [Fold 1] Epoch 16 time: 4.22s | train_acc=0.8341 val_acc=0.8390
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8341 - loss: 0.5038 - val_accuracy: 0.8390 - val_loss: 0.4908 - learning_rate: 0.0010
# Epoch 17/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8420 - loss: 0.4990⏱️ [Fold 1] Epoch 17 time: 4.19s | train_acc=0.8350 val_acc=0.8618
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8350 - loss: 0.4984 - val_accuracy: 0.8618 - val_loss: 0.4339 - learning_rate: 0.0010
# Epoch 18/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8373 - loss: 0.4963⏱️ [Fold 1] Epoch 18 time: 4.15s | train_acc=0.8367 val_acc=0.8486
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8367 - loss: 0.4940 - val_accuracy: 0.8486 - val_loss: 0.4721 - learning_rate: 0.0010
# Epoch 19/30
# 139/286 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8335 - loss: 0.5322⏱️ [Fold 1] Epoch 19 time: 1.32s | train_acc=0.8400 val_acc=0.7927
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8400 - loss: 0.4854 - val_accuracy: 0.7927 - val_loss: 0.5832 - learning_rate: 0.0010
# Epoch 20/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8481 - loss: 0.4738⏱️ [Fold 1] Epoch 20 time: 4.26s | train_acc=0.8483 val_acc=0.8294
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8483 - loss: 0.4653 - val_accuracy: 0.8294 - val_loss: 0.5194 - learning_rate: 0.0010
# Epoch 21/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8390 - loss: 0.4982⏱️ [Fold 1] Epoch 21 time: 4.22s | train_acc=0.8453 val_acc=0.8635
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8453 - loss: 0.4659 - val_accuracy: 0.8635 - val_loss: 0.4126 - learning_rate: 0.0010
# Epoch 22/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8415 - loss: 0.4810⏱️ [Fold 1] Epoch 22 time: 4.34s | train_acc=0.8411 val_acc=0.8443
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8411 - loss: 0.4730 - val_accuracy: 0.8443 - val_loss: 0.4372 - learning_rate: 0.0010
# Epoch 23/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8467 - loss: 0.4568⏱️ [Fold 1] Epoch 23 time: 4.29s | train_acc=0.8547 val_acc=0.8749
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8547 - loss: 0.4426 - val_accuracy: 0.8749 - val_loss: 0.4025 - learning_rate: 0.0010
# Epoch 24/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8680 - loss: 0.4204⏱️ [Fold 1] Epoch 24 time: 4.29s | train_acc=0.8678 val_acc=0.8933
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8678 - loss: 0.4127 - val_accuracy: 0.8933 - val_loss: 0.3487 - learning_rate: 0.0010
# Epoch 25/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8659 - loss: 0.4132⏱️ [Fold 1] Epoch 25 time: 4.25s | train_acc=0.8626 val_acc=0.8775
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8626 - loss: 0.4117 - val_accuracy: 0.8775 - val_loss: 0.3721 - learning_rate: 0.0010
# Epoch 26/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8720 - loss: 0.4147⏱️ [Fold 1] Epoch 26 time: 4.33s | train_acc=0.8728 val_acc=0.8828
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8728 - loss: 0.4044 - val_accuracy: 0.8828 - val_loss: 0.3821 - learning_rate: 0.0010
# Epoch 27/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8600 - loss: 0.4372⏱️ [Fold 1] Epoch 27 time: 2.80s | train_acc=0.8720 val_acc=0.8845
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8720 - loss: 0.4052 - val_accuracy: 0.8845 - val_loss: 0.3831 - learning_rate: 0.0010
# Epoch 28/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8790 - loss: 0.3942⏱️ [Fold 1] Epoch 28 time: 4.35s | train_acc=0.8781 val_acc=0.8880
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8781 - loss: 0.3937 - val_accuracy: 0.8880 - val_loss: 0.3386 - learning_rate: 0.0010
# Epoch 29/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8605 - loss: 0.4278⏱️ [Fold 1] Epoch 29 time: 4.12s | train_acc=0.8647 val_acc=0.8688
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8647 - loss: 0.4125 - val_accuracy: 0.8688 - val_loss: 0.4017 - learning_rate: 0.0010
# Epoch 30/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8753 - loss: 0.3994⏱️ [Fold 1] Epoch 30 time: 4.74s | train_acc=0.8783 val_acc=0.8819
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8783 - loss: 0.3879 - val_accuracy: 0.8819 - val_loss: 0.3805 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 28.
# 2025-10-31 13:45:44.961214: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_288', 8 bytes spill stores, 8 bytes spill loads
# Fold 1 Results:
#   Validation Accuracy: 0.8880
#   Validation Loss: 0.3386
#   Fold Training Time: 148.59 seconds
# [INFO] Saved fold model: quantum_cnn_fold1.keras
#   *** New best model! ***
#
# ======================================================================
# FOLD 2/5
# ======================================================================
# Train samples: 4569, Val samples: 1143
# Epoch 1/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.3233 - loss: 1.4226⏱️ [Fold 2] Epoch 1 time: 19.49s | train_acc=0.3751 val_acc=0.2528
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 19s 46ms/step - accuracy: 0.3751 - loss: 1.3129 - val_accuracy: 0.2528 - val_loss: 1.8733 - learning_rate: 0.0010
# Epoch 2/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4899 - loss: 1.1851⏱️ [Fold 2] Epoch 2 time: 4.37s | train_acc=0.5277 val_acc=0.5932
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.5277 - loss: 1.1411 - val_accuracy: 0.5932 - val_loss: 1.1229 - learning_rate: 0.0010
# Epoch 3/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5861 - loss: 1.0494⏱️ [Fold 2] Epoch 3 time: 4.20s | train_acc=0.5914 val_acc=0.5967
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.5914 - loss: 1.0283 - val_accuracy: 0.5967 - val_loss: 1.0954 - learning_rate: 0.0010
# Epoch 4/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6287 - loss: 0.9688⏱️ [Fold 2] Epoch 4 time: 4.33s | train_acc=0.6430 val_acc=0.7130
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6430 - loss: 0.9269 - val_accuracy: 0.7130 - val_loss: 0.7801 - learning_rate: 0.0010
# Epoch 5/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6755 - loss: 0.8580⏱️ [Fold 2] Epoch 5 time: 4.16s | train_acc=0.6907 val_acc=0.7148
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.6907 - loss: 0.8152 - val_accuracy: 0.7148 - val_loss: 0.7409 - learning_rate: 0.0010
# Epoch 6/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7186 - loss: 0.7440 ⏱️ [Fold 2] Epoch 6 time: 2.30s | train_acc=0.7319 val_acc=0.7638
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7319 - loss: 0.7218 - val_accuracy: 0.7638 - val_loss: 0.6923 - learning_rate: 0.0010
# Epoch 7/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7615 - loss: 0.6961⏱️ [Fold 2] Epoch 7 time: 4.15s | train_acc=0.7645 val_acc=0.7227
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7645 - loss: 0.6777 - val_accuracy: 0.7227 - val_loss: 0.7606 - learning_rate: 0.0010
# Epoch 8/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7918 - loss: 0.6278⏱️ [Fold 2] Epoch 8 time: 4.35s | train_acc=0.7886 val_acc=0.8049
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.7886 - loss: 0.6239 - val_accuracy: 0.8049 - val_loss: 0.6239 - learning_rate: 0.0010
# Epoch 9/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8084 - loss: 0.5922⏱️ [Fold 2] Epoch 9 time: 4.24s | train_acc=0.8011 val_acc=0.7795
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8011 - loss: 0.5885 - val_accuracy: 0.7795 - val_loss: 0.6483 - learning_rate: 0.0010
# Epoch 10/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8108 - loss: 0.5703⏱️ [Fold 2] Epoch 10 time: 4.28s | train_acc=0.8050 val_acc=0.7874
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8050 - loss: 0.5767 - val_accuracy: 0.7874 - val_loss: 0.6208 - learning_rate: 0.0010
# Epoch 11/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8172 - loss: 0.5491⏱️ [Fold 2] Epoch 11 time: 4.19s | train_acc=0.8098 val_acc=0.8320
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8098 - loss: 0.5549 - val_accuracy: 0.8320 - val_loss: 0.5226 - learning_rate: 0.0010
# Epoch 12/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7949 - loss: 0.5698⏱️ [Fold 2] Epoch 12 time: 4.44s | train_acc=0.8015 val_acc=0.8390
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8015 - loss: 0.5654 - val_accuracy: 0.8390 - val_loss: 0.5038 - learning_rate: 0.0010
# Epoch 13/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8185 - loss: 0.5512⏱️ [Fold 2] Epoch 13 time: 4.20s | train_acc=0.8135 val_acc=0.8486
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8135 - loss: 0.5467 - val_accuracy: 0.8486 - val_loss: 0.4977 - learning_rate: 0.0010
# Epoch 14/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8347 - loss: 0.5056⏱️ [Fold 2] Epoch 14 time: 4.29s | train_acc=0.8339 val_acc=0.8373
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8339 - loss: 0.5071 - val_accuracy: 0.8373 - val_loss: 0.5316 - learning_rate: 0.0010
# Epoch 15/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8351 - loss: 0.4960⏱️ [Fold 2] Epoch 15 time: 4.19s | train_acc=0.8308 val_acc=0.8145
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8308 - loss: 0.4958 - val_accuracy: 0.8145 - val_loss: 0.5148 - learning_rate: 0.0010
# Epoch 16/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8409 - loss: 0.4826⏱️ [Fold 2] Epoch 16 time: 4.29s | train_acc=0.8315 val_acc=0.8583
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8315 - loss: 0.4939 - val_accuracy: 0.8583 - val_loss: 0.4656 - learning_rate: 0.0010
# Epoch 17/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8364 - loss: 0.4980⏱️ [Fold 2] Epoch 17 time: 4.05s | train_acc=0.8352 val_acc=0.8565
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8352 - loss: 0.4966 - val_accuracy: 0.8565 - val_loss: 0.4677 - learning_rate: 0.0010
# Epoch 18/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8527 - loss: 0.4549⏱️ [Fold 2] Epoch 18 time: 4.19s | train_acc=0.8470 val_acc=0.8451
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8470 - loss: 0.4676 - val_accuracy: 0.8451 - val_loss: 0.4942 - learning_rate: 0.0010
# Epoch 19/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8449 - loss: 0.4698⏱️ [Fold 2] Epoch 19 time: 4.08s | train_acc=0.8468 val_acc=0.8206
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8468 - loss: 0.4649 - val_accuracy: 0.8206 - val_loss: 0.5123 - learning_rate: 0.0010
# Epoch 20/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8497 - loss: 0.4471⏱️ [Fold 2] Epoch 20 time: 4.25s | train_acc=0.8503 val_acc=0.8346
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8503 - loss: 0.4407 - val_accuracy: 0.8346 - val_loss: 0.4646 - learning_rate: 0.0010
# Epoch 21/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8584 - loss: 0.4420⏱️ [Fold 2] Epoch 21 time: 4.10s | train_acc=0.8623 val_acc=0.8574
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8623 - loss: 0.4328 - val_accuracy: 0.8574 - val_loss: 0.4450 - learning_rate: 0.0010
# Epoch 22/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8616 - loss: 0.4199⏱️ [Fold 2] Epoch 22 time: 4.13s | train_acc=0.8555 val_acc=0.8539
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8555 - loss: 0.4259 - val_accuracy: 0.8539 - val_loss: 0.4695 - learning_rate: 0.0010
# Epoch 23/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8555 - loss: 0.4404⏱️ [Fold 2] Epoch 23 time: 4.06s | train_acc=0.8580 val_acc=0.8653
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8580 - loss: 0.4340 - val_accuracy: 0.8653 - val_loss: 0.4272 - learning_rate: 0.0010
# Epoch 24/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8707 - loss: 0.4113⏱️ [Fold 2] Epoch 24 time: 4.23s | train_acc=0.8724 val_acc=0.8679
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8724 - loss: 0.4051 - val_accuracy: 0.8679 - val_loss: 0.4348 - learning_rate: 0.0010
# Epoch 25/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8696 - loss: 0.4119⏱️ [Fold 2] Epoch 25 time: 4.22s | train_acc=0.8693 val_acc=0.8723
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8693 - loss: 0.4091 - val_accuracy: 0.8723 - val_loss: 0.4179 - learning_rate: 0.0010
# Epoch 26/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8784 - loss: 0.3816⏱️ [Fold 2] Epoch 26 time: 4.20s | train_acc=0.8770 val_acc=0.8749
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8770 - loss: 0.3875 - val_accuracy: 0.8749 - val_loss: 0.4241 - learning_rate: 0.0010
# Epoch 27/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8776 - loss: 0.3844⏱️ [Fold 2] Epoch 27 time: 3.67s | train_acc=0.8711 val_acc=0.8670
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8711 - loss: 0.4014 - val_accuracy: 0.8670 - val_loss: 0.4174 - learning_rate: 0.0010
# Epoch 28/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8863 - loss: 0.3700⏱️ [Fold 2] Epoch 28 time: 3.58s | train_acc=0.8816 val_acc=0.8635
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8816 - loss: 0.3774 - val_accuracy: 0.8635 - val_loss: 0.4444 - learning_rate: 0.0010
# Epoch 29/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8879 - loss: 0.3606⏱️ [Fold 2] Epoch 29 time: 3.59s | train_acc=0.8884 val_acc=0.8548
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8884 - loss: 0.3603 - val_accuracy: 0.8548 - val_loss: 0.4965 - learning_rate: 0.0010
# Epoch 30/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9000 - loss: 0.3433⏱️ [Fold 2] Epoch 30 time: 3.64s | train_acc=0.8982 val_acc=0.8784
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8982 - loss: 0.3440 - val_accuracy: 0.8784 - val_loss: 0.3987 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 30.
#
# Fold 2 Results:
#   Validation Accuracy: 0.8784
#   Validation Loss: 0.3987
#   Fold Training Time: 137.92 seconds
# [INFO] Saved fold model: quantum_cnn_fold2.keras
#
# ======================================================================
# FOLD 3/5
# ======================================================================
# Train samples: 4570, Val samples: 1142
# Epoch 1/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4328 - loss: 1.2676⏱️ [Fold 3] Epoch 1 time: 22.45s | train_acc=0.5107 val_acc=0.2338
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 22s 55ms/step - accuracy: 0.5107 - loss: 1.1746 - val_accuracy: 0.2338 - val_loss: 1.3590 - learning_rate: 0.0010
# Epoch 2/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6468 - loss: 0.9786⏱️ [Fold 3] Epoch 2 time: 3.99s | train_acc=0.6468 val_acc=0.6226
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6468 - loss: 0.9504 - val_accuracy: 0.6226 - val_loss: 0.8992 - learning_rate: 0.0010
# Epoch 3/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6754 - loss: 0.8645⏱️ [Fold 3] Epoch 3 time: 3.99s | train_acc=0.6838 val_acc=0.6611
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6838 - loss: 0.8382 - val_accuracy: 0.6611 - val_loss: 0.8590 - learning_rate: 0.0010
# Epoch 4/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7200 - loss: 0.7616⏱️ [Fold 3] Epoch 4 time: 3.95s | train_acc=0.7278 val_acc=0.7513
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7278 - loss: 0.7404 - val_accuracy: 0.7513 - val_loss: 0.6490 - learning_rate: 0.0010
# Epoch 5/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7406 - loss: 0.6948⏱️ [Fold 3] Epoch 5 time: 3.98s | train_acc=0.7352 val_acc=0.7583
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7352 - loss: 0.6855 - val_accuracy: 0.7583 - val_loss: 0.6415 - learning_rate: 0.0010
# Epoch 6/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7427 - loss: 0.6576⏱️ [Fold 3] Epoch 6 time: 3.94s | train_acc=0.7409 val_acc=0.7461
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7409 - loss: 0.6452 - val_accuracy: 0.7461 - val_loss: 0.5884 - learning_rate: 0.0010
# Epoch 7/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7560 - loss: 0.6222⏱️ [Fold 3] Epoch 7 time: 3.99s | train_acc=0.7453 val_acc=0.7531
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7453 - loss: 0.6234 - val_accuracy: 0.7531 - val_loss: 0.6045 - learning_rate: 0.0010
# Epoch 8/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7517 - loss: 0.5957⏱️ [Fold 3] Epoch 8 time: 3.94s | train_acc=0.7519 val_acc=0.7487
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7519 - loss: 0.5884 - val_accuracy: 0.7487 - val_loss: 0.6110 - learning_rate: 0.0010
# Epoch 9/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7557 - loss: 0.6010⏱️ [Fold 3] Epoch 9 time: 4.07s | train_acc=0.7540 val_acc=0.7329
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7540 - loss: 0.6010 - val_accuracy: 0.7329 - val_loss: 0.6397 - learning_rate: 0.0010
# Epoch 10/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7840 - loss: 0.5834⏱️ [Fold 3] Epoch 10 time: 3.97s | train_acc=0.7792 val_acc=0.6506
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7792 - loss: 0.5845 - val_accuracy: 0.6506 - val_loss: 1.0690 - learning_rate: 0.0010
# Epoch 11/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7953 - loss: 0.5789
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# ⏱️ [Fold 3] Epoch 11 time: 3.95s | train_acc=0.7952 val_acc=0.7828
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7952 - loss: 0.5745 - val_accuracy: 0.7828 - val_loss: 0.6440 - learning_rate: 0.0010
# Epoch 12/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8266 - loss: 0.5274⏱️ [Fold 3] Epoch 12 time: 3.95s | train_acc=0.8232 val_acc=0.8345
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8232 - loss: 0.5221 - val_accuracy: 0.8345 - val_loss: 0.5425 - learning_rate: 5.0000e-04
# Epoch 13/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8274 - loss: 0.5217⏱️ [Fold 3] Epoch 13 time: 3.99s | train_acc=0.8328 val_acc=0.8327
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8328 - loss: 0.5097 - val_accuracy: 0.8327 - val_loss: 0.5325 - learning_rate: 5.0000e-04
# Epoch 14/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8208 - loss: 0.5089⏱️ [Fold 3] Epoch 14 time: 4.03s | train_acc=0.8330 val_acc=0.8345
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8330 - loss: 0.4959 - val_accuracy: 0.8345 - val_loss: 0.5383 - learning_rate: 5.0000e-04
# Epoch 15/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8440 - loss: 0.4846⏱️ [Fold 3] Epoch 15 time: 3.97s | train_acc=0.8449 val_acc=0.8065
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8449 - loss: 0.4791 - val_accuracy: 0.8065 - val_loss: 0.5584 - learning_rate: 5.0000e-04
# Epoch 16/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8434 - loss: 0.4918⏱️ [Fold 3] Epoch 16 time: 3.98s | train_acc=0.8429 val_acc=0.8433
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8429 - loss: 0.4780 - val_accuracy: 0.8433 - val_loss: 0.5246 - learning_rate: 5.0000e-04
# Epoch 17/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8415 - loss: 0.4780⏱️ [Fold 3] Epoch 17 time: 3.97s | train_acc=0.8464 val_acc=0.8327
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8464 - loss: 0.4650 - val_accuracy: 0.8327 - val_loss: 0.4919 - learning_rate: 5.0000e-04
# Epoch 18/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8495 - loss: 0.4563⏱️ [Fold 3] Epoch 18 time: 4.01s | train_acc=0.8536 val_acc=0.8249
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8536 - loss: 0.4509 - val_accuracy: 0.8249 - val_loss: 0.5473 - learning_rate: 5.0000e-04
# Epoch 19/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8526 - loss: 0.4522⏱️ [Fold 3] Epoch 19 time: 3.97s | train_acc=0.8567 val_acc=0.8021
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8567 - loss: 0.4409 - val_accuracy: 0.8021 - val_loss: 0.5600 - learning_rate: 5.0000e-04
# Epoch 20/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8611 - loss: 0.4470⏱️ [Fold 3] Epoch 20 time: 4.00s | train_acc=0.8613 val_acc=0.8538
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8613 - loss: 0.4367 - val_accuracy: 0.8538 - val_loss: 0.4612 - learning_rate: 5.0000e-04
# Epoch 21/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8590 - loss: 0.4314⏱️ [Fold 3] Epoch 21 time: 3.95s | train_acc=0.8621 val_acc=0.8249
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8621 - loss: 0.4267 - val_accuracy: 0.8249 - val_loss: 0.5204 - learning_rate: 5.0000e-04
# Epoch 22/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8632 - loss: 0.4258⏱️ [Fold 3] Epoch 22 time: 4.04s | train_acc=0.8626 val_acc=0.8765
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8626 - loss: 0.4235 - val_accuracy: 0.8765 - val_loss: 0.4302 - learning_rate: 5.0000e-04
# Epoch 23/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8628 - loss: 0.4308⏱️ [Fold 3] Epoch 23 time: 3.95s | train_acc=0.8646 val_acc=0.8722
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8646 - loss: 0.4196 - val_accuracy: 0.8722 - val_loss: 0.4444 - learning_rate: 5.0000e-04
# Epoch 24/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8670 - loss: 0.4197⏱️ [Fold 3] Epoch 24 time: 4.05s | train_acc=0.8705 val_acc=0.8590
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8705 - loss: 0.4094 - val_accuracy: 0.8590 - val_loss: 0.4386 - learning_rate: 5.0000e-04
# Epoch 25/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8746 - loss: 0.4033⏱️ [Fold 3] Epoch 25 time: 4.01s | train_acc=0.8777 val_acc=0.8249
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8777 - loss: 0.3951 - val_accuracy: 0.8249 - val_loss: 0.5248 - learning_rate: 5.0000e-04
# Epoch 26/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8733 - loss: 0.4002⏱️ [Fold 3] Epoch 26 time: 3.95s | train_acc=0.8799 val_acc=0.8827
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8799 - loss: 0.3897 - val_accuracy: 0.8827 - val_loss: 0.4184 - learning_rate: 5.0000e-04
# Epoch 27/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8687 - loss: 0.4086⏱️ [Fold 3] Epoch 27 time: 3.98s | train_acc=0.8748 val_acc=0.8538
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8748 - loss: 0.3954 - val_accuracy: 0.8538 - val_loss: 0.4516 - learning_rate: 5.0000e-04
# Epoch 28/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8790 - loss: 0.3847⏱️ [Fold 3] Epoch 28 time: 3.95s | train_acc=0.8823 val_acc=0.8520
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8823 - loss: 0.3743 - val_accuracy: 0.8520 - val_loss: 0.4523 - learning_rate: 5.0000e-04
# Epoch 29/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8814 - loss: 0.3765⏱️ [Fold 3] Epoch 29 time: 4.01s | train_acc=0.8836 val_acc=0.8713
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8836 - loss: 0.3654 - val_accuracy: 0.8713 - val_loss: 0.4261 - learning_rate: 5.0000e-04
# Epoch 30/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8823 - loss: 0.3883⏱️ [Fold 3] Epoch 30 time: 3.96s | train_acc=0.8906 val_acc=0.8476
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8906 - loss: 0.3672 - val_accuracy: 0.8476 - val_loss: 0.4509 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 26.
# 2025-10-31 13:50:29.420597: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_288', 8 bytes spill stores, 8 bytes spill loads
# Fold 3 Results:
#   Validation Accuracy: 0.8827
#   Validation Loss: 0.4184
#   Fold Training Time: 138.41 seconds
# [INFO] Saved fold model: quantum_cnn_fold3.keras
#
# ======================================================================
# FOLD 4/5
# ======================================================================
# Train samples: 4570, Val samples: 1142
# Epoch 1/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3208 - loss: 1.3502⏱️ [Fold 4] Epoch 1 time: 20.34s | train_acc=0.3947 val_acc=0.3932
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.3947 - loss: 1.2830 - val_accuracy: 0.3932 - val_loss: 1.4318 - learning_rate: 0.0010
# Epoch 2/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5550 - loss: 1.0885⏱️ [Fold 4] Epoch 2 time: 4.09s | train_acc=0.5856 val_acc=0.5727
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.5856 - loss: 1.0490 - val_accuracy: 0.5727 - val_loss: 1.1030 - learning_rate: 0.0010
# Epoch 3/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6794 - loss: 0.9231⏱️ [Fold 4] Epoch 3 time: 4.07s | train_acc=0.6993 val_acc=0.7154
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6993 - loss: 0.8897 - val_accuracy: 0.7154 - val_loss: 0.8141 - learning_rate: 0.0010
# Epoch 4/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7347 - loss: 0.7840⏱️ [Fold 4] Epoch 4 time: 4.08s | train_acc=0.7319 val_acc=0.7741
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7319 - loss: 0.7818 - val_accuracy: 0.7741 - val_loss: 0.7062 - learning_rate: 0.0010
# Epoch 5/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7477 - loss: 0.7034⏱️ [Fold 4] Epoch 5 time: 4.08s | train_acc=0.7409 val_acc=0.7662
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7409 - loss: 0.7114 - val_accuracy: 0.7662 - val_loss: 0.6721 - learning_rate: 0.0010
# Epoch 6/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7658 - loss: 0.6673⏱️ [Fold 4] Epoch 6 time: 4.04s | train_acc=0.7608 val_acc=0.8152
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7608 - loss: 0.6718 - val_accuracy: 0.8152 - val_loss: 0.6006 - learning_rate: 0.0010
# Epoch 7/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7715 - loss: 0.6426⏱️ [Fold 4] Epoch 7 time: 4.04s | train_acc=0.7718 val_acc=0.7312
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7718 - loss: 0.6413 - val_accuracy: 0.7312 - val_loss: 0.7227 - learning_rate: 0.0010
# Epoch 8/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7765 - loss: 0.6285⏱️ [Fold 4] Epoch 8 time: 4.04s | train_acc=0.7735 val_acc=0.8021
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7735 - loss: 0.6321 - val_accuracy: 0.8021 - val_loss: 0.5925 - learning_rate: 0.0010
# Epoch 9/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7779 - loss: 0.6062⏱️ [Fold 4] Epoch 9 time: 4.14s | train_acc=0.7858 val_acc=0.8284
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7858 - loss: 0.5980 - val_accuracy: 0.8284 - val_loss: 0.5765 - learning_rate: 0.0010
# Epoch 10/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7960 - loss: 0.5848⏱️ [Fold 4] Epoch 10 time: 4.01s | train_acc=0.8035 val_acc=0.8319
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8035 - loss: 0.5804 - val_accuracy: 0.8319 - val_loss: 0.5402 - learning_rate: 0.0010
# Epoch 11/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8083 - loss: 0.5567⏱️ [Fold 4] Epoch 11 time: 3.99s | train_acc=0.8033 val_acc=0.7697
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8033 - loss: 0.5679 - val_accuracy: 0.7697 - val_loss: 0.6845 - learning_rate: 0.0010
# Epoch 12/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8157 - loss: 0.5491⏱️ [Fold 4] Epoch 12 time: 4.01s | train_acc=0.8092 val_acc=0.8327
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8092 - loss: 0.5591 - val_accuracy: 0.8327 - val_loss: 0.5612 - learning_rate: 0.0010
# Epoch 13/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8226 - loss: 0.5418⏱️ [Fold 4] Epoch 13 time: 4.00s | train_acc=0.8131 val_acc=0.8459
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8131 - loss: 0.5526 - val_accuracy: 0.8459 - val_loss: 0.5058 - learning_rate: 0.0010
# Epoch 14/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8369 - loss: 0.4887⏱️ [Fold 4] Epoch 14 time: 3.99s | train_acc=0.8276 val_acc=0.8109
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8276 - loss: 0.5121 - val_accuracy: 0.8109 - val_loss: 0.5276 - learning_rate: 0.0010
# Epoch 15/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8245 - loss: 0.4948⏱️ [Fold 4] Epoch 15 time: 3.99s | train_acc=0.8223 val_acc=0.8651
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8223 - loss: 0.5063 - val_accuracy: 0.8651 - val_loss: 0.4646 - learning_rate: 0.0010
# Epoch 16/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8427 - loss: 0.4798⏱️ [Fold 4] Epoch 16 time: 4.01s | train_acc=0.8341 val_acc=0.8555
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8341 - loss: 0.4946 - val_accuracy: 0.8555 - val_loss: 0.4571 - learning_rate: 0.0010
# Epoch 17/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8425 - loss: 0.4638⏱️ [Fold 4] Epoch 17 time: 3.99s | train_acc=0.8381 val_acc=0.8608
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8381 - loss: 0.4760 - val_accuracy: 0.8608 - val_loss: 0.4504 - learning_rate: 0.0010
# Epoch 18/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8561 - loss: 0.4482⏱️ [Fold 4] Epoch 18 time: 3.99s | train_acc=0.8549 val_acc=0.8389
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8549 - loss: 0.4529 - val_accuracy: 0.8389 - val_loss: 0.4867 - learning_rate: 0.0010
# Epoch 19/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8529 - loss: 0.4516⏱️ [Fold 4] Epoch 19 time: 4.07s | train_acc=0.8538 val_acc=0.8485
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8538 - loss: 0.4549 - val_accuracy: 0.8485 - val_loss: 0.4536 - learning_rate: 0.0010
# Epoch 20/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8537 - loss: 0.4403⏱️ [Fold 4] Epoch 20 time: 4.00s | train_acc=0.8519 val_acc=0.8643
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8519 - loss: 0.4499 - val_accuracy: 0.8643 - val_loss: 0.4647 - learning_rate: 0.0010
# Epoch 21/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8644 - loss: 0.4328⏱️ [Fold 4] Epoch 21 time: 3.98s | train_acc=0.8530 val_acc=0.8800
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8530 - loss: 0.4480 - val_accuracy: 0.8800 - val_loss: 0.4137 - learning_rate: 0.0010
# Epoch 22/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8633 - loss: 0.4271⏱️ [Fold 4] Epoch 22 time: 4.00s | train_acc=0.8573 val_acc=0.8827
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8573 - loss: 0.4362 - val_accuracy: 0.8827 - val_loss: 0.3937 - learning_rate: 0.0010
# Epoch 23/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8728 - loss: 0.4020⏱️ [Fold 4] Epoch 23 time: 4.01s | train_acc=0.8691 val_acc=0.8827
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8691 - loss: 0.4142 - val_accuracy: 0.8827 - val_loss: 0.3997 - learning_rate: 0.0010
# Epoch 24/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8751 - loss: 0.3999⏱️ [Fold 4] Epoch 24 time: 4.07s | train_acc=0.8742 val_acc=0.8757
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8742 - loss: 0.4047 - val_accuracy: 0.8757 - val_loss: 0.4159 - learning_rate: 0.0010
# Epoch 25/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8778 - loss: 0.3818⏱️ [Fold 4] Epoch 25 time: 3.99s | train_acc=0.8700 val_acc=0.8651
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8700 - loss: 0.4046 - val_accuracy: 0.8651 - val_loss: 0.4418 - learning_rate: 0.0010
# Epoch 26/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8812 - loss: 0.3805⏱️ [Fold 4] Epoch 26 time: 3.98s | train_acc=0.8768 val_acc=0.8844
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8768 - loss: 0.3937 - val_accuracy: 0.8844 - val_loss: 0.3869 - learning_rate: 0.0010
# Epoch 27/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8824 - loss: 0.3794⏱️ [Fold 4] Epoch 27 time: 4.07s | train_acc=0.8781 val_acc=0.8538
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8781 - loss: 0.3906 - val_accuracy: 0.8538 - val_loss: 0.4285 - learning_rate: 0.0010
# Epoch 28/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8847 - loss: 0.3648⏱️ [Fold 4] Epoch 28 time: 4.01s | train_acc=0.8814 val_acc=0.8914
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8814 - loss: 0.3744 - val_accuracy: 0.8914 - val_loss: 0.3699 - learning_rate: 0.0010
# Epoch 29/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8866 - loss: 0.3656⏱️ [Fold 4] Epoch 29 time: 4.07s | train_acc=0.8875 val_acc=0.8862
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8875 - loss: 0.3714 - val_accuracy: 0.8862 - val_loss: 0.3976 - learning_rate: 0.0010
# Epoch 30/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8928 - loss: 0.3483⏱️ [Fold 4] Epoch 30 time: 4.02s | train_acc=0.8884 val_acc=0.8765
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8884 - loss: 0.3637 - val_accuracy: 0.8765 - val_loss: 0.3990 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 28.
#
# Fold 4 Results:
#   Validation Accuracy: 0.8914
#   Validation Loss: 0.3699
#   Fold Training Time: 137.69 seconds
# [INFO] Saved fold model: quantum_cnn_fold4.keras
#   *** New best model! ***
#
# ======================================================================
# FOLD 5/5
# ======================================================================
# Train samples: 4570, Val samples: 1142
# Epoch 1/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.3675 - loss: 1.3132⏱️ [Fold 5] Epoch 1 time: 19.94s | train_acc=0.4398 val_acc=0.2828
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 20s 44ms/step - accuracy: 0.4398 - loss: 1.2118 - val_accuracy: 0.2828 - val_loss: 1.3943 - learning_rate: 0.0010
# Epoch 2/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5941 - loss: 1.0340⏱️ [Fold 5] Epoch 2 time: 4.01s | train_acc=0.6245 val_acc=0.7233
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6245 - loss: 0.9964 - val_accuracy: 0.7233 - val_loss: 0.9365 - learning_rate: 0.0010
# Epoch 3/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6911 - loss: 0.8856⏱️ [Fold 5] Epoch 3 time: 3.98s | train_acc=0.7000 val_acc=0.7898
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7000 - loss: 0.8638 - val_accuracy: 0.7898 - val_loss: 0.7722 - learning_rate: 0.0010
# Epoch 4/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7356 - loss: 0.8067⏱️ [Fold 5] Epoch 4 time: 4.09s | train_acc=0.7381 val_acc=0.7662
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7381 - loss: 0.7859 - val_accuracy: 0.7662 - val_loss: 0.7536 - learning_rate: 0.0010
# Epoch 5/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7529 - loss: 0.7404⏱️ [Fold 5] Epoch 5 time: 5.00s | train_acc=0.7554 val_acc=0.8257
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7554 - loss: 0.7256 - val_accuracy: 0.8257 - val_loss: 0.6550 - learning_rate: 0.0010
# Epoch 6/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7672 - loss: 0.6931⏱️ [Fold 5] Epoch 6 time: 3.99s | train_acc=0.7637 val_acc=0.8030
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7637 - loss: 0.6911 - val_accuracy: 0.8030 - val_loss: 0.6864 - learning_rate: 0.0010
# Epoch 7/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7740 - loss: 0.6748⏱️ [Fold 5] Epoch 7 time: 4.09s | train_acc=0.7705 val_acc=0.8152
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7705 - loss: 0.6691 - val_accuracy: 0.8152 - val_loss: 0.6134 - learning_rate: 0.0010
# Epoch 8/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7815 - loss: 0.6443⏱️ [Fold 5] Epoch 8 time: 3.97s | train_acc=0.7904 val_acc=0.7014
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7904 - loss: 0.6372 - val_accuracy: 0.7014 - val_loss: 0.7557 - learning_rate: 0.0010
# Epoch 9/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8055 - loss: 0.6174⏱️ [Fold 5] Epoch 9 time: 4.07s | train_acc=0.8011 val_acc=0.8363
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8011 - loss: 0.6179 - val_accuracy: 0.8363 - val_loss: 0.5675 - learning_rate: 0.0010
# Epoch 10/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8071 - loss: 0.6041⏱️ [Fold 5] Epoch 10 time: 4.01s | train_acc=0.8129 val_acc=0.8380
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8129 - loss: 0.5879 - val_accuracy: 0.8380 - val_loss: 0.5711 - learning_rate: 0.0010
# Epoch 11/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8204 - loss: 0.5634⏱️ [Fold 5] Epoch 11 time: 4.02s | train_acc=0.8177 val_acc=0.8476
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8177 - loss: 0.5665 - val_accuracy: 0.8476 - val_loss: 0.5450 - learning_rate: 0.0010
# Epoch 12/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8309 - loss: 0.5504⏱️ [Fold 5] Epoch 12 time: 4.07s | train_acc=0.8300 val_acc=0.8573
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8300 - loss: 0.5449 - val_accuracy: 0.8573 - val_loss: 0.4950 - learning_rate: 0.0010
# Epoch 13/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8315 - loss: 0.5416⏱️ [Fold 5] Epoch 13 time: 4.04s | train_acc=0.8319 val_acc=0.8704
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8319 - loss: 0.5254 - val_accuracy: 0.8704 - val_loss: 0.4832 - learning_rate: 0.0010
# Epoch 14/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8324 - loss: 0.5311⏱️ [Fold 5] Epoch 14 time: 4.05s | train_acc=0.8260 val_acc=0.8529
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8260 - loss: 0.5348 - val_accuracy: 0.8529 - val_loss: 0.5042 - learning_rate: 0.0010
# Epoch 15/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8313 - loss: 0.5138⏱️ [Fold 5] Epoch 15 time: 4.06s | train_acc=0.8361 val_acc=0.8345
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8361 - loss: 0.5077 - val_accuracy: 0.8345 - val_loss: 0.4953 - learning_rate: 0.0010
# Epoch 16/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8499 - loss: 0.4835⏱️ [Fold 5] Epoch 16 time: 3.99s | train_acc=0.8455 val_acc=0.8450
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8455 - loss: 0.4887 - val_accuracy: 0.8450 - val_loss: 0.4882 - learning_rate: 0.0010
# Epoch 17/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8500 - loss: 0.4910⏱️ [Fold 5] Epoch 17 time: 4.02s | train_acc=0.8505 val_acc=0.8687
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8505 - loss: 0.4825 - val_accuracy: 0.8687 - val_loss: 0.4686 - learning_rate: 0.0010
# Epoch 18/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8444 - loss: 0.4889⏱️ [Fold 5] Epoch 18 time: 4.08s | train_acc=0.8438 val_acc=0.8897
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8438 - loss: 0.4795 - val_accuracy: 0.8897 - val_loss: 0.4085 - learning_rate: 0.0010
# Epoch 19/30
# 284/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8448 - loss: 0.4764⏱️ [Fold 5] Epoch 19 time: 3.99s | train_acc=0.8484 val_acc=0.8555
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8484 - loss: 0.4674 - val_accuracy: 0.8555 - val_loss: 0.4715 - learning_rate: 0.0010
# Epoch 20/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8521 - loss: 0.4848⏱️ [Fold 5] Epoch 20 time: 4.03s | train_acc=0.8495 val_acc=0.8660
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8495 - loss: 0.4728 - val_accuracy: 0.8660 - val_loss: 0.4506 - learning_rate: 0.0010
# Epoch 21/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8571 - loss: 0.4599⏱️ [Fold 5] Epoch 21 time: 4.03s | train_acc=0.8597 val_acc=0.8835
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8597 - loss: 0.4521 - val_accuracy: 0.8835 - val_loss: 0.4268 - learning_rate: 0.0010
# Epoch 22/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8691 - loss: 0.4104⏱️ [Fold 5] Epoch 22 time: 4.07s | train_acc=0.8674 val_acc=0.8853
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8674 - loss: 0.4239 - val_accuracy: 0.8853 - val_loss: 0.4142 - learning_rate: 0.0010
# Epoch 23/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8673 - loss: 0.4303
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# ⏱️ [Fold 5] Epoch 23 time: 4.07s | train_acc=0.8648 val_acc=0.8590
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8648 - loss: 0.4330 - val_accuracy: 0.8590 - val_loss: 0.4330 - learning_rate: 0.0010
# Epoch 24/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8806 - loss: 0.4005⏱️ [Fold 5] Epoch 24 time: 3.99s | train_acc=0.8849 val_acc=0.8993
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8849 - loss: 0.3869 - val_accuracy: 0.8993 - val_loss: 0.3816 - learning_rate: 5.0000e-04
# Epoch 25/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8860 - loss: 0.3921⏱️ [Fold 5] Epoch 25 time: 3.98s | train_acc=0.8849 val_acc=0.8914
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8849 - loss: 0.3847 - val_accuracy: 0.8914 - val_loss: 0.4051 - learning_rate: 5.0000e-04
# Epoch 26/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8953 - loss: 0.3789⏱️ [Fold 5] Epoch 26 time: 4.08s | train_acc=0.8921 val_acc=0.8905
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8921 - loss: 0.3728 - val_accuracy: 0.8905 - val_loss: 0.3965 - learning_rate: 5.0000e-04
# Epoch 27/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8969 - loss: 0.3636⏱️ [Fold 5] Epoch 27 time: 3.98s | train_acc=0.8963 val_acc=0.8932
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8963 - loss: 0.3610 - val_accuracy: 0.8932 - val_loss: 0.3954 - learning_rate: 5.0000e-04
# Epoch 28/30
# 282/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9003 - loss: 0.3589⏱️ [Fold 5] Epoch 28 time: 4.17s | train_acc=0.8945 val_acc=0.9019
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8945 - loss: 0.3604 - val_accuracy: 0.9019 - val_loss: 0.3546 - learning_rate: 5.0000e-04
# Epoch 29/30
# 285/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8960 - loss: 0.3617⏱️ [Fold 5] Epoch 29 time: 4.01s | train_acc=0.8978 val_acc=0.9046
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8978 - loss: 0.3563 - val_accuracy: 0.9046 - val_loss: 0.3638 - learning_rate: 5.0000e-04
# Epoch 30/30
# 283/286 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9045 - loss: 0.3440⏱️ [Fold 5] Epoch 30 time: 4.03s | train_acc=0.9035 val_acc=0.9063
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9035 - loss: 0.3387 - val_accuracy: 0.9063 - val_loss: 0.3543 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 30.
#
# Fold 5 Results:
#   Validation Accuracy: 0.9063
#   Validation Loss: 0.3543
#   Fold Training Time: 138.43 seconds
# [INFO] Saved fold model: quantum_cnn_fold5.keras
#   *** New best model! ***
# [INFO] Epoch timing data saved to: logs/qcnn_epoch_times.csv
# [INFO] Epoch time plot saved to: logs/qcnn_epoch_time_plot.png
#
# ======================================================================
# CROSS-VALIDATION RESULTS
# ======================================================================
# Fold Accuracies: ['0.8880', '0.8784', '0.8827', '0.8914', '0.9063']
# Mean CV Accuracy: 0.8894 (+/- 0.0096)
# Best Fold Accuracy: 0.9063
# Training history saved to training_history.png
#
# ======================================================================
# TEST SET EVALUATION
# ======================================================================
# 2025-10-31 13:55:18.183396: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_288', 8 bytes spill stores, 8 bytes spill loads
# Test Accuracy: 0.8535
# Test Loss: 0.4935
#
# ----------------------------------------------------------------------
# CLASSIFICATION REPORT
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#       glioma       0.93      0.79      0.85       300
#   meningioma       0.73      0.62      0.67       306
#      notumor       0.88      0.99      0.93       405
#    pituitary       0.85      0.98      0.91       300
#
#     accuracy                           0.85      1311
#    macro avg       0.85      0.84      0.84      1311
# weighted avg       0.85      0.85      0.85      1311
#
#
# ----------------------------------------------------------------------
# PER-CLASS PERFORMANCE ANALYSIS
# ----------------------------------------------------------------------
#
# GLIOMA:
#   Precision: 0.9328
#   Recall:    0.7867
#   F1-Score:  0.8535
#   Support:   300
#
# MENINGIOMA:
#   Precision: 0.7326
#   Recall:    0.6176
#   F1-Score:  0.6702
#   Support:   306
#
# NOTUMOR:
#   Precision: 0.8775
#   Recall:    0.9901
#   F1-Score:  0.9304
#   Support:   405
#
# PITUITARY:
#   Precision: 0.8542
#   Recall:    0.9767
#   F1-Score:  0.9114
#   Support:   300
# Confusion matrix saved to confusion_matrix.png
# Quantum layer not found for visualization
#
# ======================================================================
# Model saved as 'quantum_cnn_brain_tumor_model.keras'
# ======================================================================
#
# ✓ Training and evaluation complete!
#
# Generated files:
#   1. quantum_cnn_brain_tumor_model.keras - Trained best model
#   2. quantum_cnn_fold{n}.keras - Per-fold saved models
#   3. logs/qcnn_epoch_times.csv - Epoch timing & metrics
#   4. logs/qcnn_epoch_time_plot.png - Epoch time plot
#   5. training_history.png - Training curves
#   6. confusion_matrix.png - Confusion matrix
#   7. gradcam_results.png - Grad-CAM visualizations
#   8. quantum_layer_viz.png - Quantum layer activations

# %%
from tensorflow.keras.models import load_model

model=load_model("quantum_cnn_brain_tumor_model.keras",  custom_objects={"QuantumInspiredLayer": QuantumInspiredLayer})
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_30 (Conv2D)              │ (None, 64, 64, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_30          │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_31 (Conv2D)              │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_31          │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_32          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 32, 32, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_33          │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_34          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_35          │ (None, 16, 16, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 64)             │       524,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_23 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 4)              │           260 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ quantum_layer                   │ (None, 4)              │            48 │
# │ (QuantumInspiredLayer)          │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 4)              │            20 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,626,066 (6.20 MB)
#  Trainable params: 812,584 (3.10 MB)
#  Non-trainable params: 896 (3.50 KB)
#  Optimizer params: 812,586 (3.10 MB)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Load log data
df = pd.read_csv("logs/qcnn_epoch_times.csv")
df.head()
# Out:
#    Fold  Epoch    TimeSec  TrainAcc    ValAcc  TrainLoss   ValLoss     LR
# 0     1      1  32.205839  0.373824  0.403325   1.314979  1.511331  0.001
# 1     1      2   4.213028  0.587218  0.601925   1.135234  1.218136  0.001
# 2     1      3   2.170944  0.680236  0.800525   0.982491  0.849008  0.001
# 3     1      4   4.214010  0.722259  0.793526   0.869444  0.803235  0.001
# 4     1      5   4.317802  0.743051  0.794401   0.792270  0.715933  0.001

# %%
plt.figure(figsize=(10,6))
sns.lineplot(
    data=df, 
    x='Epoch', y='TrainAcc', 
    hue='Fold', 
    marker='o', 
    palette='viridis', 
    alpha=0.8, 
    linewidth=2
)
sns.lineplot(
    data=df, 
    x='Epoch', y='ValAcc', 
    hue='Fold', 
    marker='s', 
    palette='magma', 
    alpha=0.8, 
    linewidth=2,
    legend=False
)

plt.title("Training vs Validation Accuracy Across Folds (QCNN)", fontsize=14, fontweight='bold')
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)
plt.grid(alpha=0.3)
plt.legend(title='Fold', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=df, x='Epoch', y='TrainLoss', hue='Fold', palette='cool', linewidth=2, marker='o')
sns.lineplot(data=df, x='Epoch', y='ValLoss', hue='Fold', palette='rocket', linewidth=2, linestyle='--', marker='s', legend=False)

plt.title("Training vs Validation Loss (QCNN)", fontsize=14, fontweight='bold')
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.grid(alpha=0.3)
plt.legend(title='Fold', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Epoch', y='TimeSec', hue='Fold', palette='Spectral')
plt.title("Training Time per Epoch across Folds", fontsize=14, fontweight='bold')
plt.xlabel("Epoch")
plt.ylabel("Time (seconds)")
plt.grid(alpha=0.2)
plt.tight_layout()
plt.show()

# %%
fig = px.line(
    df, 
    x='Epoch', 
    y=['TrainAcc', 'ValAcc'], 
    color_discrete_sequence=['#1f77b4', '#ff7f0e'],
    title='QCNN Training and Validation Accuracy (Interactive)',
    markers=True
)
fig.update_layout(
    template='plotly_dark',
    xaxis_title='Epoch',
    yaxis_title='Accuracy',
    legend_title_text='Metric',
    font=dict(size=12)
)
fig.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[['TrainAcc','ValAcc','TrainLoss','ValLoss','TimeSec','LR']].corr(), 
            annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap of Training Metrics", fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
summary = df.groupby('Fold')[['TrainAcc','ValAcc','TrainLoss','ValLoss','TimeSec']].agg(['mean','max','min'])
display(summary)
# Out:
#       TrainAcc                        ValAcc                     TrainLoss  \
#           mean       max       min      mean       max       min      mean
# Fold
# 1     0.798089  0.878310  0.373824  0.818868  0.893263  0.403325  0.590957
# 2     0.791771  0.898227  0.375137  0.792359  0.878390  0.252843  0.580805
# 3     0.807141  0.890591  0.510722  0.782370  0.882662  0.233800  0.541699
# 4     0.803071  0.888403  0.394748  0.813368  0.891419  0.393170  0.562222
# 5     0.814055  0.903501  0.439825  0.829480  0.906305  0.282837  0.557561
#
#                            ValLoss                       TimeSec             \
#            max       min      mean       max       min      mean        max
# Fold
# 1     1.314979  0.387914  0.570177  1.511331  0.338620  4.923742  32.205839
# 2     1.312889  0.343992  0.610301  1.873297  0.398693  4.581882  19.485760
# 3     1.174631  0.365413  0.595958  1.359027  0.418382  4.598357  22.449274
# 4     1.283039  0.363702  0.562088  1.431772  0.369875  4.572444  20.339080
# 5     1.211776  0.338721  0.548049  1.394340  0.354311  4.596937  19.942510
#
#
#            min
# Fold
# 1     1.316690
# 2     2.295686
# 3     3.937412
# 4     3.978777
# 5     3.971668
