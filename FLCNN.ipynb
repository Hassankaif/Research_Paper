# %% [markdown]
# Federated CNN MODEL USING SDG OPTIMIZER WITH MOMENTUM=0.9

# %%
import os
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try: # allow memory growth
        for g in gpus:
            tf.config.experimental.set_memory_growth(g, True)
    except Exception as e:
        print("GPU config error:", e)

# %%
import os
import time
import csv
import json
import gc
from datetime import datetime

import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, Callback
from tensorflow.python.framework.errors_impl import ResourceExhaustedError

from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support

# %%
# Set seeds
np.random.seed(42)
tf.random.set_seed(42)

# %%
# Ensure logs and models dirs
os.makedirs("sdg-logs", exist_ok=True)
os.makedirs("sdg-models", exist_ok=True)
os.makedirs("tmp_models", exist_ok=True)

# %%
# -------------------------
# Timing callback
# -------------------------
class TimingCallback(Callback):
    def __init__(self, fold_no, client_id, epoch_time_records):
        super().__init__()
        self.fold_no = fold_no
        self.client_id = client_id
        self.epoch_times = []
        self.epoch_time_records = epoch_time_records

    def on_epoch_begin(self, epoch, logs=None):
        self._epoch_start = time.time()

    def on_epoch_end(self, epoch, logs=None):
        t = time.time() - self._epoch_start
        self.epoch_times.append(t)
        try:
            lr = float(tf.keras.backend.get_value(self.model.optimizer.learning_rate))
        except Exception:
            lr = None
        train_acc = logs.get('accuracy')
        val_acc = logs.get('val_accuracy')
        train_loss = logs.get('loss')
        val_loss = logs.get('val_loss')
        # record: fold, client, epoch, time, train_acc, val_acc, train_loss, val_loss, lr
        self.epoch_time_records.append([self.fold_no, self.client_id, epoch + 1, t, train_acc, val_acc, train_loss, val_loss, lr])
        print(f"⏱️ [Fold {self.fold_no} Client {self.client_id}] Epoch {epoch+1} time: {t:.2f}s | train_acc={train_acc:.4f} val_acc={val_acc}")

# %%
# -------------------------
# ClientSequence: on-the-fly loading
# -------------------------
class ClientSequence(keras.utils.Sequence):
    def __init__(self, filepaths, labels, img_size=(64, 64), batch_size=16, num_classes=4, shuffle=True):
        self.filepaths = np.array(filepaths)
        self.labels = np.array(labels)
        self.img_size = img_size
        self.batch_size = batch_size
        self.num_classes = num_classes
        self.shuffle = shuffle
        self.indexes = np.arange(len(self.filepaths))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.filepaths) / float(self.batch_size)))

    def __getitem__(self, index):
        batch_idx = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        batch_files = self.filepaths[batch_idx]
        batch_labels = self.labels[batch_idx]
        X = np.zeros((len(batch_files), *self.img_size, 3), dtype=np.float32)
        y = np.zeros((len(batch_files), self.num_classes), dtype=np.float32)
        for i, fp in enumerate(batch_files):
            img = cv2.imread(fp)
            if img is None:
                img = np.zeros((self.img_size[0], self.img_size[1], 3), dtype=np.uint8)
            else:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = cv2.resize(img, self.img_size)
            img = img.astype(np.float32) / 255.0
            y[i, int(batch_labels[i])] = 1.0
            X[i] = img
        return X, y

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

# %%
# -------------------------
# Federated class
# -------------------------
class FederatedBrainTumorCNN:
    def __init__(self, num_clients=5, img_size=(64, 64), num_classes=4, class_names=None):
        self.num_clients = num_clients
        self.img_size = img_size
        self.num_classes = num_classes
        self.class_names = class_names or ['glioma', 'meningioma', 'notumor', 'pituitary']
        self.global_model = None
        self.history = {'val_accuracy': [], 'val_loss': []}

    def create_cnn_model(self):
        model = models.Sequential([
            layers.Input(shape=(*self.img_size, 3)),
            layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(0.25),

            layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(0.25),

            layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
            layers.BatchNormalization(),
            layers.MaxPooling2D((2, 2)),
            layers.Dropout(0.25),

            layers.Flatten(),
            layers.Dense(64, activation='relu'),
            layers.BatchNormalization(),
            layers.Dropout(0.5),
            layers.Dense(self.num_classes, activation='softmax')
        ])


        model.compile(
            optimizer=keras.optimizers.SGD(learning_rate=0.001, momentum=0.9),
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        return model

    def load_data_generators(self, train_dir, test_dir, batch_size=16):
        train_datagen = ImageDataGenerator(
            rescale=1./255,
            rotation_range=20,
            width_shift_range=0.2,
            height_shift_range=0.2,
            horizontal_flip=True,
            zoom_range=0.2,
            fill_mode='nearest',
            validation_split=0.2
        )
        test_datagen = ImageDataGenerator(rescale=1./255)

        train_generator = train_datagen.flow_from_directory(
            train_dir,
            target_size=self.img_size,
            batch_size=batch_size,
            class_mode='categorical',
            subset='training',
            shuffle=True
        )

        val_generator = train_datagen.flow_from_directory(
            train_dir,
            target_size=self.img_size,
            batch_size=batch_size,
            class_mode='categorical',
            subset='validation',
            shuffle=False
        )

        test_generator = test_datagen.flow_from_directory(
            test_dir,
            target_size=self.img_size,
            batch_size=batch_size,
            class_mode='categorical',
            shuffle=False
        )

        idx_to_class = {v: k for k, v in train_generator.class_indices.items()}
        self.class_names = [idx_to_class[i] for i in range(len(idx_to_class))]
        return train_generator, val_generator, test_generator

    def split_filepaths_for_clients(self, train_generator):
        filepaths = np.array(train_generator.filepaths)
        labels = np.array(train_generator.classes, dtype=int)
        indices = np.arange(len(filepaths))
        np.random.shuffle(indices)
        splits = np.array_split(indices, self.num_clients)
        client_filelists = []
        for s in splits:
            client_filelists.append((filepaths[s].tolist(), labels[s].tolist()))
        return client_filelists

    def federated_averaging(self, client_weights):
        avg_weights = []
        for weights_tuple in zip(*client_weights):
            avg_weights.append(np.mean(weights_tuple, axis=0))
        return avg_weights

    # -------------------------
    # Federated training (with timing, comm bytes, logs)
    # -------------------------
    def train_federated(self, train_dir, val_generator, num_rounds=5, local_epochs=6, batch_size=16, start_round=1):
        print("\n========== FEDERATED TRAINING STARTED ==========")
        print(f"Clients: {self.num_clients}, Rounds: {num_rounds}, Local epochs: {local_epochs}, Batch size: {batch_size}")

        # ensure global model initialized
        if self.global_model is None:
            if start_round > 1:
                raise ValueError("Load checkpoint into self.global_model before resuming.")
            self.global_model = self.create_cnn_model()

        base_datagen = ImageDataGenerator(rescale=1./255)
        base_gen = base_datagen.flow_from_directory(train_dir, target_size=self.img_size, batch_size=batch_size,
                                                    class_mode='categorical', shuffle=False)
        client_filelists = self.split_filepaths_for_clients(base_gen)

        # Prepare logging CSVs
        epoch_time_records = []  # rows: [round, client_id, epoch, time_sec, train_acc, val_acc, train_loss, val_loss, lr]
        comm_records = []        # rows: [round, client_id, bytes_sent_server_to_client, bytes_returned_client_to_server]
        round_summary_rows = []  # rows: [round, total_comm_bytes, round_time_sec, val_loss, val_acc]

        # history keys
        if not hasattr(self, 'history') or not isinstance(self.history, dict):
            self.history = {'val_accuracy': [], 'val_loss': []}

        for round_num in range(start_round - 1, num_rounds):
            print(f"\n========== ROUND {round_num + 1}/{num_rounds} ==========")
            round_start_time = time.time()
            client_weights = []
            total_comm_this_round = 0
            per_client_times = []

            for client_id, (filepaths, labels) in enumerate(client_filelists):
                print(f"  -> Client {client_id + 1}/{self.num_clients} | samples: {len(filepaths)}")
                # server -> client: size of current global model weights
                server_weights = self.global_model.get_weights()
                bytes_server_to_client = sum([w.nbytes for w in server_weights])
                # record server->client comm (simulating send)
                # NOTE: in many FL systems server sends only updated params; here we record full weights for clarity
                print(f"    bytes server->client: {bytes_server_to_client:,} bytes")

                # create client model and load global weights
                client_model = self.create_cnn_model()
                client_model.set_weights(self.global_model.get_weights())

                # create sequence loader for client
                seq = ClientSequence(filepaths, labels, img_size=self.img_size, batch_size=batch_size,
                                     num_classes=self.num_classes, shuffle=True)

                # timing callback per client to get per-epoch times
                timing_cb = TimingCallback(round_num + 1, client_id + 1, epoch_time_records)
                callbacks = [
                    timing_cb,
                    EarlyStopping(patience=3, restore_best_weights=True, verbose=0, monitor='loss'),
                    ReduceLROnPlateau(factor=0.5, patience=2, verbose=0, monitor='loss')
                ]

                client_start_time = time.time()
                try:
                    client_model.fit(seq, epochs=local_epochs, verbose=1, callbacks=callbacks)
                except ResourceExhaustedError as oom:
                    print("!! OOM during client training:", oom)
                    # attempt to save and reduce batch/size then retry (omitted here for brevity)
                    raise
                client_time = time.time() - client_start_time
                per_client_times.append(client_time)
                print(f"    client {client_id+1} training time: {client_time:.2f}s")

                # client -> server: size of client weights returned
                client_w = client_model.get_weights()
                bytes_client_to_server = sum([w.nbytes for w in client_w])
                print(f"    bytes client->server: {bytes_client_to_server:,} bytes")

                # append communication record
                comm_records.append([round_num + 1, client_id + 1, bytes_server_to_client, bytes_client_to_server])
                total_comm_this_round += (bytes_server_to_client + bytes_client_to_server)

                # append client weights for FedAvg
                client_weights.append(client_w)

                # cleanup client model to free memory
                try:
                    del client_model
                except Exception:
                    pass
                gc.collect()

            # Federated averaging
            print("Aggregating client weights (FedAvg)...")
            averaged_weights = []
            for layer_weights in zip(*client_weights):
                stacked = np.stack(layer_weights, axis=0)
                averaged = np.mean(stacked, axis=0)
                averaged_weights.append(averaged)

            self.global_model.set_weights(averaged_weights)

            # Evaluate global model on validation set
            print("Evaluating global model on validation set...")
            val_loss, val_accuracy = self.global_model.evaluate(val_generator, verbose=1)
            print(f"[Round {round_num + 1}] Val loss: {val_loss:.4f} | Val accuracy: {val_accuracy:.4f}")

            if len(self.history['val_loss']) < (round_num + 1):
                self.history['val_loss'].append(float(val_loss))
                self.history['val_accuracy'].append(float(val_accuracy))

            # Save checkpoint after each round
            ckpt_path = os.path.join("sdg-models", f"federated_model_round_{round_num + 1}.keras")
            try:
                self.global_model.save(ckpt_path)
                print(f"[✓] Saved checkpoint: {ckpt_path}")
            except Exception as e:
                print("Warning: failed to save checkpoint:", e)

            round_time = time.time() - round_start_time
            round_summary_rows.append([round_num + 1, total_comm_this_round, round_time, float(val_loss), float(val_accuracy)])
            # lightweight cleanup
            gc.collect()

        # --- Save logs to CSVs ---
        # epoch timing
        epoch_csv = os.path.join("sdg-logs", "federated_epoch_times.csv")
        with open(epoch_csv, "w", newline="") as f:
            writer = csv.writer(f)
            writer.writerow(["Round", "Client", "Epoch", "TimeSec", "TrainAcc", "ValAcc", "TrainLoss", "ValLoss", "LR"])
            writer.writerows(epoch_time_records)
        print(f"[LOG] Saved epoch timing to: {epoch_csv}")

        # communication bytes per client/round
        comm_csv = os.path.join("sdg-logs", "comm_bytes_per_round.csv")
        with open(comm_csv, "w", newline="") as f:
            writer = csv.writer(f)
            writer.writerow(["Round", "Client", "Bytes_Server_to_Client", "Bytes_Client_to_Server"])
            writer.writerows(comm_records)
        print(f"[LOG] Saved communication bytes to: {comm_csv}")

        # round summary
        round_csv = os.path.join("sdg-logs", "federated_training_log.csv")
        with open(round_csv, "w", newline="") as f:
            writer = csv.writer(f)
            writer.writerow(["Round", "Total_Comm_Bytes", "RoundTimeSec", "ValLoss", "ValAcc"])
            writer.writerows(round_summary_rows)
        print(f"[LOG] Saved round summary to: {round_csv}")

        print("\n========== FEDERATED TRAINING COMPLETED ==========")
        return self.global_model

    # -------------------------
    # K-fold cross validation (saves models per fold)
    # -------------------------
    def kfold_cross_validation(self, train_dir, k_folds=5, batch_size=16):
        print("\n" + "="*70)
        print("K-FOLD CROSS-VALIDATION")
        print("="*70)

        datagen = ImageDataGenerator(rescale=1./255)
        full_generator = datagen.flow_from_directory(
            train_dir,
            target_size=self.img_size,
            batch_size=batch_size,
            class_mode='categorical',
            shuffle=False
        )

        filepaths = np.array(full_generator.filepaths)
        labels = np.array(full_generator.classes, dtype=int)
        x_dummy = np.arange(len(filepaths))
        kfold = KFold(n_splits=k_folds, shuffle=True, random_state=42)
        fold_scores = []

        for fold, (train_idx, val_idx) in enumerate(kfold.split(x_dummy)):
            print(f"\n-- Fold {fold + 1}/{k_folds} --")
            train_files = filepaths[train_idx]
            train_labels = labels[train_idx]
            val_files = filepaths[val_idx]
            val_labels = labels[val_idx]

            train_seq = ClientSequence(train_files, train_labels, img_size=self.img_size, batch_size=batch_size,
                                       num_classes=self.num_classes, shuffle=True)
            val_seq = ClientSequence(val_files, val_labels, img_size=self.img_size, batch_size=batch_size,
                                     num_classes=self.num_classes, shuffle=False)

            model = self.create_cnn_model()
            callbacks = [
                EarlyStopping(patience=5, restore_best_weights=True, verbose=0),
                ReduceLROnPlateau(factor=0.5, patience=3, verbose=0)
            ]

            model.fit(train_seq, validation_data=val_seq, epochs=30, verbose=1, callbacks=callbacks)
            _, accuracy = model.evaluate(val_seq, verbose=0)
            fold_scores.append(float(accuracy))
            print(f"Fold {fold + 1} Accuracy: {accuracy:.4f}")

            # Save fold model
            fold_model_path = os.path.join("sdg-models", f"kfold_model_fold{fold+1}.keras")
            try:
                model.save(fold_model_path)
                print(f"[✓] Saved K-Fold model: {fold_model_path}")
            except Exception as e:
                print("Warning: could not save k-fold model:", e)

            # cleanup
            try:
                del model
            except Exception:
                pass
            tf.keras.backend.clear_session()
            gc.collect()

        # Save fold results CSV
        kfold_csv = os.path.join("sdg-logs", "kfold_results.csv")
        with open(kfold_csv, "w", newline="") as f:
            writer = csv.writer(f)
            writer.writerow(["Fold", "Accuracy"])
            for i, acc in enumerate(fold_scores, start=1):
                writer.writerow([i, acc])
        print(f"[LOG] Saved k-fold results to: {kfold_csv}")

        print(f"\nK-Fold Cross-Validation Mean Accuracy: {np.mean(fold_scores):.4f} (+/- {np.std(fold_scores):.4f})")
        return fold_scores

    # -------------------------
    # Evaluation and plotting
    # -------------------------
    def evaluate_model(self, test_generator):
        print("\n" + "="*70)
        print("MODEL EVALUATION ON TEST SET")
        print("="*70)

        y_pred_probs = self.global_model.predict(test_generator, verbose=1)
        y_pred = np.argmax(y_pred_probs, axis=1)
        y_true = test_generator.classes

        accuracy = accuracy_score(y_true, y_pred)
        print(f"Test Accuracy: {accuracy:.4f}")

        report = classification_report(y_true, y_pred, target_names=self.class_names, digits=4)
        print(report)
        # save classification report
        with open(os.path.join("logs", "classification_report.txt"), "w") as f:
            f.write(report)

        cm = confusion_matrix(y_true, y_pred)
        return y_true, y_pred, y_pred_probs, cm, accuracy

    def plot_training_history(self):
        fig, axes = plt.subplots(1, 2, figsize=(14, 5))
        axes[0].plot(self.history['val_accuracy'], marker='o', linewidth=2)
        axes[0].set_title('Federated Learning - Validation Accuracy')
        axes[0].set_xlabel('Federated Round')
        axes[0].set_ylabel('Accuracy')
        axes[0].grid(True)
        axes[0].set_ylim([0, 1])

        axes[1].plot(self.history['val_loss'], marker='o', linewidth=2)
        axes[1].set_title('Federated Learning - Validation Loss')
        axes[1].set_xlabel('Federated Round')
        axes[1].set_ylabel('Loss')
        axes[1].grid(True)

        plt.tight_layout()
        plt.savefig('training_history.png', dpi=300, bbox_inches='tight')
        plt.show()
        print("Saved: training_history.png")

    def plot_confusion_matrix(self, cm):
        plt.figure(figsize=(9, 7))
        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=self.class_names, yticklabels=self.class_names)
        plt.title('Confusion Matrix')
        plt.ylabel('True')
        plt.xlabel('Predicted')
        plt.tight_layout()
        plt.savefig('confusion_matrix.png', dpi=300, bbox_inches='tight')
        plt.show()
        print("Saved: confusion_matrix.png")

    def plot_performance_metrics(self, y_true, y_pred):
        precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average=None)
        x = np.arange(len(self.class_names))
        width = 0.25
        fig, ax = plt.subplots(figsize=(10, 5))
        ax.bar(x - width, precision, width, label='Precision')
        ax.bar(x, recall, width, label='Recall')
        ax.bar(x + width, f1, width, label='F1')
        ax.set_xticks(x)
        ax.set_xticklabels(self.class_names, rotation=45)
        ax.set_ylim([0, 1.05])
        ax.legend()
        plt.tight_layout()
        plt.savefig('performance_metrics.png', dpi=300, bbox_inches='tight')
        plt.show()
        print("Saved: performance_metrics.png")

    def save_results(self, fold_scores, test_accuracy):
        results = {
            'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
            'model_config': {'num_clients': self.num_clients, 'image_size': self.img_size, 'num_classes': self.num_classes},
            'kfold_results': {'fold_scores': [float(s) for s in fold_scores], 'mean_accuracy': float(np.mean(fold_scores)),
                              'std_accuracy': float(np.std(fold_scores))},
            'test_accuracy': float(test_accuracy),
            'training_history': {'val_accuracy': [float(x) for x in self.history['val_accuracy']],
                                 'val_loss': [float(x) for x in self.history['val_loss']]}
        }
        with open('federated_learning_results.json', 'w') as f:
            json.dump(results, f, indent=4)
        print("Saved: federated_learning_results.json")

# %%
# -------------------------
# main runner (example usage)
# -------------------------
def main():
    TRAIN_DIR = 'Brain_Tumor_data/Training'
    TEST_DIR = 'Brain_Tumor_data/Testing'

    NUM_CLIENTS = 5
    NUM_FEDERATED_ROUNDS = 5
    LOCAL_EPOCHS = 6
    K_FOLDS = 5
    BATCH_SIZE = 16

    print("CONFIG:")
    print(f"  clients: {NUM_CLIENTS}, fed rounds: {NUM_FEDERATED_ROUNDS}, local epochs: {LOCAL_EPOCHS}, kfolds: {K_FOLDS}, batch_size: {BATCH_SIZE}")

    fed = FederatedBrainTumorCNN(num_clients=NUM_CLIENTS, img_size=(64, 64))
    train_gen, val_gen, test_gen = fed.load_data_generators(TRAIN_DIR, TEST_DIR, batch_size=BATCH_SIZE)
    print("Samples:", train_gen.samples, "Validation:", val_gen.samples, "Test:", test_gen.samples)

    # K-fold (optional)
    fold_scores = fed.kfold_cross_validation(TRAIN_DIR, k_folds=K_FOLDS, batch_size=BATCH_SIZE)

    # Federated training
    global_model = fed.train_federated(TRAIN_DIR, val_gen, num_rounds=NUM_FEDERATED_ROUNDS,
                                       local_epochs=LOCAL_EPOCHS, batch_size=BATCH_SIZE)

    fed.plot_training_history()

    # Evaluate
    y_true, y_pred, y_pred_probs, cm, test_acc = fed.evaluate_model(test_gen)
    fed.plot_confusion_matrix(cm)
    fed.plot_performance_metrics(y_true, y_pred)
    fed.save_results(fold_scores, test_acc)

    # Save final models
    try:
        global_model.save('federated_brain_tumor_model.h5')
        print("Saved model: federated_brain_tumor_model.h5")
        global_model.save('federated_brain_tumor_model.keras')
        print("Saved model: federated_brain_tumor_model.keras")
    except Exception as e:
        print("Warning: could not save final model:", e)

# %%
if __name__ == "__main__":
    main()
# Out:
# CONFIG:
#   clients: 5, fed rounds: 5, local epochs: 6, kfolds: 5, batch_size: 16
# Found 4571 images belonging to 4 classes.
# Found 1141 images belonging to 4 classes.
# Found 1311 images belonging to 4 classes.
# Samples: 4571 Validation: 1141 Test: 1311
#
# ======================================================================
# K-FOLD CROSS-VALIDATION
# ======================================================================
# Found 5712 images belonging to 4 classes.
#
# -- Fold 1/5 --
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761923768.873936   65299 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1767 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2050, pci bus id: 0000:01:00.0, compute capability: 8.6
# /mnt/c/Users/hassa/aiml/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 2025-10-31 15:16:15.236594: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f0c800166d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-31 15:16:15.236633: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 2050, Compute Capability 8.6
# 2025-10-31 15:16:15.633667: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-31 15:16:16.307557: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91300
#   2/286 ━━━━━━━━━━━━━━━━━━━━ 28s 101ms/step - accuracy: 0.3125 - loss: 2.2077
# I0000 00:00:1761923788.927707   68966 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 55s 134ms/step - accuracy: 0.6625 - loss: 0.8981 - val_accuracy: 0.4926 - val_loss: 1.6349 - learning_rate: 0.0010
# Epoch 2/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 103ms/step - accuracy: 0.7757 - loss: 0.6153 - val_accuracy: 0.7568 - val_loss: 0.6498 - learning_rate: 0.0010
# Epoch 3/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 95ms/step - accuracy: 0.8179 - loss: 0.5068 - val_accuracy: 0.8443 - val_loss: 0.4520 - learning_rate: 0.0010
# Epoch 4/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.8302 - loss: 0.4513 - val_accuracy: 0.8381 - val_loss: 0.4776 - learning_rate: 0.0010
# Epoch 5/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.8415 - loss: 0.4200 - val_accuracy: 0.8618 - val_loss: 0.4085 - learning_rate: 0.0010
# Epoch 6/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.8698 - loss: 0.3793 - val_accuracy: 0.8793 - val_loss: 0.3796 - learning_rate: 0.0010
# Epoch 7/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.8731 - loss: 0.3483 - val_accuracy: 0.9055 - val_loss: 0.2770 - learning_rate: 0.0010
# Epoch 8/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 26s 91ms/step - accuracy: 0.8825 - loss: 0.3189 - val_accuracy: 0.8670 - val_loss: 0.4456 - learning_rate: 0.0010
# Epoch 9/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 96ms/step - accuracy: 0.8998 - loss: 0.2821 - val_accuracy: 0.9020 - val_loss: 0.3055 - learning_rate: 0.0010
# Epoch 10/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.8991 - loss: 0.2857 - val_accuracy: 0.8915 - val_loss: 0.3249 - learning_rate: 0.0010
# Epoch 11/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 31s 107ms/step - accuracy: 0.9133 - loss: 0.2461 - val_accuracy: 0.8941 - val_loss: 0.3329 - learning_rate: 5.0000e-04
# Epoch 12/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.9199 - loss: 0.2402 - val_accuracy: 0.9011 - val_loss: 0.2961 - learning_rate: 5.0000e-04
# Fold 1 Accuracy: 0.9055
# [✓] Saved K-Fold model: sdg-models/kfold_model_fold1.keras
#
# -- Fold 2/5 --
# Epoch 1/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 41s 119ms/step - accuracy: 0.6923 - loss: 0.8326 - val_accuracy: 0.2660 - val_loss: 2.1658 - learning_rate: 0.0010
# Epoch 2/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 100ms/step - accuracy: 0.7916 - loss: 0.5514 - val_accuracy: 0.7507 - val_loss: 0.6811 - learning_rate: 0.0010
# Epoch 3/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 104ms/step - accuracy: 0.8253 - loss: 0.4958 - val_accuracy: 0.8171 - val_loss: 0.5182 - learning_rate: 0.0010
# Epoch 4/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.8501 - loss: 0.4336 - val_accuracy: 0.8198 - val_loss: 0.4710 - learning_rate: 0.0010
# Epoch 5/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 100ms/step - accuracy: 0.8481 - loss: 0.4252 - val_accuracy: 0.8793 - val_loss: 0.3626 - learning_rate: 0.0010
# Epoch 6/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 95ms/step - accuracy: 0.8663 - loss: 0.3768 - val_accuracy: 0.8749 - val_loss: 0.3529 - learning_rate: 0.0010
# Epoch 7/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.8781 - loss: 0.3549 - val_accuracy: 0.8810 - val_loss: 0.3607 - learning_rate: 0.0010
# Epoch 8/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 95ms/step - accuracy: 0.8879 - loss: 0.3065 - val_accuracy: 0.8775 - val_loss: 0.3463 - learning_rate: 0.0010
# Epoch 9/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 100ms/step - accuracy: 0.8969 - loss: 0.2979 - val_accuracy: 0.8854 - val_loss: 0.3224 - learning_rate: 0.0010
# Epoch 10/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 94ms/step - accuracy: 0.8897 - loss: 0.2979 - val_accuracy: 0.8889 - val_loss: 0.3287 - learning_rate: 0.0010
# Epoch 11/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 92ms/step - accuracy: 0.9114 - loss: 0.2596 - val_accuracy: 0.9003 - val_loss: 0.3122 - learning_rate: 0.0010
# Epoch 12/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 105ms/step - accuracy: 0.9138 - loss: 0.2409 - val_accuracy: 0.8950 - val_loss: 0.2806 - learning_rate: 0.0010
# Epoch 13/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.9168 - loss: 0.2284 - val_accuracy: 0.9020 - val_loss: 0.2716 - learning_rate: 0.0010
# Epoch 14/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 94ms/step - accuracy: 0.9223 - loss: 0.2164 - val_accuracy: 0.9046 - val_loss: 0.2847 - learning_rate: 0.0010
# Epoch 15/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 95ms/step - accuracy: 0.9260 - loss: 0.2098 - val_accuracy: 0.8845 - val_loss: 0.3437 - learning_rate: 0.0010
# Epoch 16/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 96ms/step - accuracy: 0.9365 - loss: 0.1932 - val_accuracy: 0.9221 - val_loss: 0.2409 - learning_rate: 0.0010
# Epoch 17/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.9418 - loss: 0.1619 - val_accuracy: 0.9283 - val_loss: 0.2133 - learning_rate: 0.0010
# Epoch 18/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 95ms/step - accuracy: 0.9389 - loss: 0.1713 - val_accuracy: 0.9143 - val_loss: 0.2551 - learning_rate: 0.0010
# Epoch 19/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.9442 - loss: 0.1623 - val_accuracy: 0.9353 - val_loss: 0.2088 - learning_rate: 0.0010
# Epoch 20/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 96ms/step - accuracy: 0.9512 - loss: 0.1439 - val_accuracy: 0.9396 - val_loss: 0.1828 - learning_rate: 0.0010
# Epoch 21/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.9499 - loss: 0.1475 - val_accuracy: 0.9353 - val_loss: 0.1947 - learning_rate: 0.0010
# Epoch 22/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 99ms/step - accuracy: 0.9532 - loss: 0.1370 - val_accuracy: 0.9256 - val_loss: 0.2251 - learning_rate: 0.0010
# Epoch 23/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9562 - loss: 0.1265 - val_accuracy: 0.9466 - val_loss: 0.1919 - learning_rate: 0.0010
# Epoch 24/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.9573 - loss: 0.1171 - val_accuracy: 0.9344 - val_loss: 0.2093 - learning_rate: 5.0000e-04
# Epoch 25/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9610 - loss: 0.1175 - val_accuracy: 0.9396 - val_loss: 0.1899 - learning_rate: 5.0000e-04
# Fold 2 Accuracy: 0.9396
# [✓] Saved K-Fold model: sdg-models/kfold_model_fold2.keras
#
# -- Fold 3/5 --
# Epoch 1/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 45s 135ms/step - accuracy: 0.6902 - loss: 0.8577 - val_accuracy: 0.4343 - val_loss: 1.6415 - learning_rate: 0.0010
# Epoch 2/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 99ms/step - accuracy: 0.7976 - loss: 0.5555 - val_accuracy: 0.7697 - val_loss: 0.5991 - learning_rate: 0.0010
# Epoch 3/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.8300 - loss: 0.4795 - val_accuracy: 0.8371 - val_loss: 0.4743 - learning_rate: 0.0010
# Epoch 4/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.8407 - loss: 0.4325 - val_accuracy: 0.8634 - val_loss: 0.4002 - learning_rate: 0.0010
# Epoch 5/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.8569 - loss: 0.4076 - val_accuracy: 0.8599 - val_loss: 0.4292 - learning_rate: 0.0010
# Epoch 6/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.8724 - loss: 0.3661 - val_accuracy: 0.8476 - val_loss: 0.3918 - learning_rate: 0.0010
# Epoch 7/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.8740 - loss: 0.3465 - val_accuracy: 0.8827 - val_loss: 0.3286 - learning_rate: 0.0010
# Epoch 8/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.8871 - loss: 0.3045 - val_accuracy: 0.8827 - val_loss: 0.3428 - learning_rate: 0.0010
# Epoch 9/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.8989 - loss: 0.2838 - val_accuracy: 0.8818 - val_loss: 0.3374 - learning_rate: 0.0010
# Epoch 10/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.9007 - loss: 0.2715 - val_accuracy: 0.9168 - val_loss: 0.2440 - learning_rate: 0.0010
# Epoch 11/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9184 - loss: 0.2321 - val_accuracy: 0.8932 - val_loss: 0.3059 - learning_rate: 0.0010
# Epoch 12/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9136 - loss: 0.2392 - val_accuracy: 0.9151 - val_loss: 0.2509 - learning_rate: 0.0010
# Epoch 13/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9162 - loss: 0.2312 - val_accuracy: 0.9072 - val_loss: 0.2496 - learning_rate: 0.0010
# Epoch 14/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 100ms/step - accuracy: 0.9302 - loss: 0.2026 - val_accuracy: 0.9291 - val_loss: 0.2277 - learning_rate: 5.0000e-04
# Epoch 15/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.9350 - loss: 0.1875 - val_accuracy: 0.9422 - val_loss: 0.1794 - learning_rate: 5.0000e-04
# Epoch 16/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 33s 115ms/step - accuracy: 0.9433 - loss: 0.1706 - val_accuracy: 0.9387 - val_loss: 0.2033 - learning_rate: 5.0000e-04
# Epoch 17/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.9422 - loss: 0.1699 - val_accuracy: 0.9378 - val_loss: 0.2000 - learning_rate: 5.0000e-04
# Epoch 18/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9431 - loss: 0.1543 - val_accuracy: 0.9448 - val_loss: 0.1905 - learning_rate: 5.0000e-04
# Epoch 19/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9510 - loss: 0.1436 - val_accuracy: 0.9466 - val_loss: 0.1799 - learning_rate: 2.5000e-04
# Epoch 20/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9508 - loss: 0.1435 - val_accuracy: 0.9413 - val_loss: 0.1988 - learning_rate: 2.5000e-04
# Fold 3 Accuracy: 0.9422
# [✓] Saved K-Fold model: sdg-models/kfold_model_fold3.keras
#
# -- Fold 4/5 --
# Epoch 1/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 42s 122ms/step - accuracy: 0.6801 - loss: 0.8630 - val_accuracy: 0.3792 - val_loss: 1.6150 - learning_rate: 0.0010
# Epoch 2/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 101ms/step - accuracy: 0.7864 - loss: 0.5932 - val_accuracy: 0.5919 - val_loss: 1.0143 - learning_rate: 0.0010
# Epoch 3/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.8105 - loss: 0.5146 - val_accuracy: 0.8012 - val_loss: 0.5062 - learning_rate: 0.0010
# Epoch 4/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.8446 - loss: 0.4281 - val_accuracy: 0.8152 - val_loss: 0.4484 - learning_rate: 0.0010
# Epoch 5/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 100ms/step - accuracy: 0.8578 - loss: 0.3998 - val_accuracy: 0.8739 - val_loss: 0.3760 - learning_rate: 0.0010
# Epoch 6/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 99ms/step - accuracy: 0.8650 - loss: 0.3737 - val_accuracy: 0.7986 - val_loss: 0.5803 - learning_rate: 0.0010
# Epoch 7/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.8766 - loss: 0.3494 - val_accuracy: 0.8170 - val_loss: 0.4737 - learning_rate: 0.0010
# Epoch 8/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 101ms/step - accuracy: 0.8781 - loss: 0.3287 - val_accuracy: 0.8240 - val_loss: 0.4558 - learning_rate: 0.0010
# Epoch 9/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 99ms/step - accuracy: 0.8930 - loss: 0.2948 - val_accuracy: 0.8993 - val_loss: 0.3148 - learning_rate: 5.0000e-04
# Epoch 10/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 101ms/step - accuracy: 0.9007 - loss: 0.2746 - val_accuracy: 0.9168 - val_loss: 0.2666 - learning_rate: 5.0000e-04
# Epoch 11/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 94ms/step - accuracy: 0.9053 - loss: 0.2657 - val_accuracy: 0.8993 - val_loss: 0.3134 - learning_rate: 5.0000e-04
# Epoch 12/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9204 - loss: 0.2358 - val_accuracy: 0.9256 - val_loss: 0.2620 - learning_rate: 5.0000e-04
# Epoch 13/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9162 - loss: 0.2432 - val_accuracy: 0.9116 - val_loss: 0.2833 - learning_rate: 5.0000e-04
# Epoch 14/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.9133 - loss: 0.2446 - val_accuracy: 0.9299 - val_loss: 0.2142 - learning_rate: 5.0000e-04
# Epoch 15/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.9219 - loss: 0.2222 - val_accuracy: 0.9151 - val_loss: 0.2853 - learning_rate: 5.0000e-04
# Epoch 16/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 95ms/step - accuracy: 0.9232 - loss: 0.2218 - val_accuracy: 0.9361 - val_loss: 0.1960 - learning_rate: 5.0000e-04
# Epoch 17/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 95ms/step - accuracy: 0.9344 - loss: 0.1964 - val_accuracy: 0.9291 - val_loss: 0.2120 - learning_rate: 5.0000e-04
# Epoch 18/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.9298 - loss: 0.1991 - val_accuracy: 0.9396 - val_loss: 0.1860 - learning_rate: 5.0000e-04
# Epoch 19/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 101ms/step - accuracy: 0.9350 - loss: 0.1802 - val_accuracy: 0.9151 - val_loss: 0.2395 - learning_rate: 5.0000e-04
# Epoch 20/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.9254 - loss: 0.2015 - val_accuracy: 0.9291 - val_loss: 0.2328 - learning_rate: 5.0000e-04
# Epoch 21/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 100ms/step - accuracy: 0.9350 - loss: 0.1773 - val_accuracy: 0.9326 - val_loss: 0.2148 - learning_rate: 5.0000e-04
# Epoch 22/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 99ms/step - accuracy: 0.9466 - loss: 0.1600 - val_accuracy: 0.9466 - val_loss: 0.1622 - learning_rate: 2.5000e-04
# Epoch 23/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 103ms/step - accuracy: 0.9451 - loss: 0.1566 - val_accuracy: 0.9396 - val_loss: 0.1735 - learning_rate: 2.5000e-04
# Epoch 24/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 31s 110ms/step - accuracy: 0.9521 - loss: 0.1455 - val_accuracy: 0.9378 - val_loss: 0.1833 - learning_rate: 2.5000e-04
# Epoch 25/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 31s 109ms/step - accuracy: 0.9510 - loss: 0.1500 - val_accuracy: 0.9501 - val_loss: 0.1661 - learning_rate: 2.5000e-04
# Epoch 26/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 95ms/step - accuracy: 0.9508 - loss: 0.1450 - val_accuracy: 0.9466 - val_loss: 0.1603 - learning_rate: 1.2500e-04
# Epoch 27/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.9505 - loss: 0.1439 - val_accuracy: 0.9413 - val_loss: 0.1746 - learning_rate: 1.2500e-04
# Epoch 28/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 27s 95ms/step - accuracy: 0.9484 - loss: 0.1416 - val_accuracy: 0.9413 - val_loss: 0.1785 - learning_rate: 1.2500e-04
# Epoch 29/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.9558 - loss: 0.1348 - val_accuracy: 0.9387 - val_loss: 0.1868 - learning_rate: 1.2500e-04
# Epoch 30/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9571 - loss: 0.1344 - val_accuracy: 0.9440 - val_loss: 0.1661 - learning_rate: 6.2500e-05
# Fold 4 Accuracy: 0.9466
# [✓] Saved K-Fold model: sdg-models/kfold_model_fold4.keras
#
# -- Fold 5/5 --
# Epoch 1/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 40s 119ms/step - accuracy: 0.6729 - loss: 0.8836 - val_accuracy: 0.3669 - val_loss: 1.6854 - learning_rate: 0.0010
# Epoch 2/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.7888 - loss: 0.5840 - val_accuracy: 0.7198 - val_loss: 0.8069 - learning_rate: 0.0010
# Epoch 3/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 102ms/step - accuracy: 0.8204 - loss: 0.4825 - val_accuracy: 0.8074 - val_loss: 0.5551 - learning_rate: 0.0010
# Epoch 4/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 100ms/step - accuracy: 0.8462 - loss: 0.4294 - val_accuracy: 0.8424 - val_loss: 0.4424 - learning_rate: 0.0010
# Epoch 5/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 99ms/step - accuracy: 0.8534 - loss: 0.3931 - val_accuracy: 0.8074 - val_loss: 0.5631 - learning_rate: 0.0010
# Epoch 6/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 99ms/step - accuracy: 0.8650 - loss: 0.3692 - val_accuracy: 0.8520 - val_loss: 0.4160 - learning_rate: 0.0010
# Epoch 7/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 100ms/step - accuracy: 0.8836 - loss: 0.3280 - val_accuracy: 0.8503 - val_loss: 0.4364 - learning_rate: 0.0010
# Epoch 8/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.8899 - loss: 0.3042 - val_accuracy: 0.8792 - val_loss: 0.3254 - learning_rate: 0.0010
# Epoch 9/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 101ms/step - accuracy: 0.8923 - loss: 0.2979 - val_accuracy: 0.8765 - val_loss: 0.3628 - learning_rate: 0.0010
# Epoch 10/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9118 - loss: 0.2492 - val_accuracy: 0.8678 - val_loss: 0.3755 - learning_rate: 0.0010
# Epoch 11/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.9118 - loss: 0.2457 - val_accuracy: 0.8914 - val_loss: 0.2906 - learning_rate: 0.0010
# Epoch 12/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9162 - loss: 0.2320 - val_accuracy: 0.8669 - val_loss: 0.3728 - learning_rate: 0.0010
# Epoch 13/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 96ms/step - accuracy: 0.9243 - loss: 0.2193 - val_accuracy: 0.9168 - val_loss: 0.2546 - learning_rate: 0.0010
# Epoch 14/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.9280 - loss: 0.2057 - val_accuracy: 0.8757 - val_loss: 0.3731 - learning_rate: 0.0010
# Epoch 15/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9368 - loss: 0.1908 - val_accuracy: 0.9081 - val_loss: 0.2845 - learning_rate: 0.0010
# Epoch 16/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 98ms/step - accuracy: 0.9346 - loss: 0.1953 - val_accuracy: 0.9229 - val_loss: 0.2206 - learning_rate: 0.0010
# Epoch 17/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 28s 97ms/step - accuracy: 0.9433 - loss: 0.1704 - val_accuracy: 0.9238 - val_loss: 0.2224 - learning_rate: 0.0010
# Epoch 18/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 102ms/step - accuracy: 0.9411 - loss: 0.1683 - val_accuracy: 0.9177 - val_loss: 0.2555 - learning_rate: 0.0010
# Epoch 19/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 31s 106ms/step - accuracy: 0.9381 - loss: 0.1716 - val_accuracy: 0.9256 - val_loss: 0.2207 - learning_rate: 0.0010
# Epoch 20/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 100ms/step - accuracy: 0.9519 - loss: 0.1374 - val_accuracy: 0.9370 - val_loss: 0.1833 - learning_rate: 5.0000e-04
# Epoch 21/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 104ms/step - accuracy: 0.9560 - loss: 0.1306 - val_accuracy: 0.9317 - val_loss: 0.2086 - learning_rate: 5.0000e-04
# Epoch 22/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 32s 110ms/step - accuracy: 0.9595 - loss: 0.1215 - val_accuracy: 0.9387 - val_loss: 0.1905 - learning_rate: 5.0000e-04
# Epoch 23/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 105ms/step - accuracy: 0.9643 - loss: 0.1136 - val_accuracy: 0.9405 - val_loss: 0.2098 - learning_rate: 5.0000e-04
# Epoch 24/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 103ms/step - accuracy: 0.9593 - loss: 0.1183 - val_accuracy: 0.9457 - val_loss: 0.1782 - learning_rate: 2.5000e-04
# Epoch 25/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 104ms/step - accuracy: 0.9615 - loss: 0.1143 - val_accuracy: 0.9457 - val_loss: 0.1858 - learning_rate: 2.5000e-04
# Epoch 26/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 104ms/step - accuracy: 0.9676 - loss: 0.0974 - val_accuracy: 0.9457 - val_loss: 0.1663 - learning_rate: 2.5000e-04
# Epoch 27/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 30s 103ms/step - accuracy: 0.9648 - loss: 0.1002 - val_accuracy: 0.9466 - val_loss: 0.1788 - learning_rate: 2.5000e-04
# Epoch 28/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 101ms/step - accuracy: 0.9685 - loss: 0.0992 - val_accuracy: 0.9413 - val_loss: 0.1757 - learning_rate: 2.5000e-04
# Epoch 29/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 29s 100ms/step - accuracy: 0.9652 - loss: 0.1018 - val_accuracy: 0.9343 - val_loss: 0.2124 - learning_rate: 2.5000e-04
# Epoch 30/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 31s 107ms/step - accuracy: 0.9716 - loss: 0.0961 - val_accuracy: 0.9510 - val_loss: 0.1627 - learning_rate: 1.2500e-04
# Fold 5 Accuracy: 0.9510
# [✓] Saved K-Fold model: sdg-models/kfold_model_fold5.keras
# [LOG] Saved k-fold results to: sdg-logs/kfold_results.csv
#
# K-Fold Cross-Validation Mean Accuracy: 0.9370 (+/- 0.0162)
#
# ========== FEDERATED TRAINING STARTED ==========
# Clients: 5, Rounds: 5, Local epochs: 6, Batch size: 16
# Found 5712 images belonging to 4 classes.
#
# ========== ROUND 1/5 ==========
#   -> Client 1/5 | samples: 1143
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.4989 - loss: 1.5580⏱️ [Fold 1 Client 1] Epoch 1 time: 20.35s | train_acc=0.5853 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 20s 183ms/step - accuracy: 0.5853 - loss: 1.2211 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7227 - loss: 0.7510⏱️ [Fold 1 Client 1] Epoch 2 time: 5.73s | train_acc=0.7253 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.7253 - loss: 0.7628 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7287 - loss: 0.6809⏱️ [Fold 1 Client 1] Epoch 3 time: 5.67s | train_acc=0.7463 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.7463 - loss: 0.6773 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7908 - loss: 0.5570⏱️ [Fold 1 Client 1] Epoch 4 time: 5.34s | train_acc=0.7647 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.7647 - loss: 0.6170 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7800 - loss: 0.5633⏱️ [Fold 1 Client 1] Epoch 5 time: 5.61s | train_acc=0.7848 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.7848 - loss: 0.5817 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8267 - loss: 0.4821⏱️ [Fold 1 Client 1] Epoch 6 time: 5.68s | train_acc=0.8066 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.8066 - loss: 0.5300 - learning_rate: 0.0010
#     client 1 training time: 48.71s
#     bytes client->server: 3,254,672 bytes
#   -> Client 2/5 | samples: 1143
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4593 - loss: 1.6289⏱️ [Fold 1 Client 2] Epoch 1 time: 16.66s | train_acc=0.5608 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 17s 144ms/step - accuracy: 0.5608 - loss: 1.2221 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6936 - loss: 0.8203⏱️ [Fold 1 Client 2] Epoch 2 time: 5.72s | train_acc=0.7034 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.7034 - loss: 0.7844 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7174 - loss: 0.7667⏱️ [Fold 1 Client 2] Epoch 3 time: 5.50s | train_acc=0.7104 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.7104 - loss: 0.7444 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7172 - loss: 0.6822⏱️ [Fold 1 Client 2] Epoch 4 time: 5.30s | train_acc=0.7340 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.7340 - loss: 0.6598 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7263 - loss: 0.6339⏱️ [Fold 1 Client 2] Epoch 5 time: 5.83s | train_acc=0.7612 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.7612 - loss: 0.6040 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7742 - loss: 0.5735⏱️ [Fold 1 Client 2] Epoch 6 time: 5.81s | train_acc=0.7760 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.7760 - loss: 0.5666 - learning_rate: 0.0010
#     client 2 training time: 45.14s
#     bytes client->server: 3,254,672 bytes
#   -> Client 3/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.5188 - loss: 1.4892⏱️ [Fold 1 Client 3] Epoch 1 time: 19.75s | train_acc=0.6165 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 20s 185ms/step - accuracy: 0.6165 - loss: 1.1506 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6882 - loss: 0.8224⏱️ [Fold 1 Client 3] Epoch 2 time: 5.60s | train_acc=0.6970 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.6970 - loss: 0.8071 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8031 - loss: 0.5756⏱️ [Fold 1 Client 3] Epoch 3 time: 5.70s | train_acc=0.7820 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.7820 - loss: 0.6008 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7842 - loss: 0.5945⏱️ [Fold 1 Client 3] Epoch 4 time: 5.74s | train_acc=0.7951 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.7951 - loss: 0.5399 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7925 - loss: 0.5345⏱️ [Fold 1 Client 3] Epoch 5 time: 5.68s | train_acc=0.7960 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.7960 - loss: 0.5325 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8487 - loss: 0.4550⏱️ [Fold 1 Client 3] Epoch 6 time: 5.80s | train_acc=0.8310 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8310 - loss: 0.4584 - learning_rate: 0.0010
#     client 3 training time: 48.62s
#     bytes client->server: 3,254,672 bytes
#   -> Client 4/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.4788 - loss: 1.5092⏱️ [Fold 1 Client 4] Epoch 1 time: 17.40s | train_acc=0.5762 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.5762 - loss: 1.1776 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6785 - loss: 0.8222⏱️ [Fold 1 Client 4] Epoch 2 time: 5.64s | train_acc=0.6988 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.6988 - loss: 0.8037 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7131 - loss: 0.7374⏱️ [Fold 1 Client 4] Epoch 3 time: 5.57s | train_acc=0.7312 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.7312 - loss: 0.7019 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7615 - loss: 0.6334⏱️ [Fold 1 Client 4] Epoch 4 time: 5.70s | train_acc=0.7881 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.7881 - loss: 0.5940 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7742 - loss: 0.6253⏱️ [Fold 1 Client 4] Epoch 5 time: 5.81s | train_acc=0.7907 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.7907 - loss: 0.5892 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7919 - loss: 0.5361⏱️ [Fold 1 Client 4] Epoch 6 time: 5.65s | train_acc=0.7872 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.7872 - loss: 0.5445 - learning_rate: 0.0010
#     client 4 training time: 46.11s
#     bytes client->server: 3,254,672 bytes
#   -> Client 5/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.4625 - loss: 1.5090⏱️ [Fold 1 Client 5] Epoch 1 time: 17.51s | train_acc=0.5718 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 18s 153ms/step - accuracy: 0.5718 - loss: 1.1860 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7168 - loss: 0.7527⏱️ [Fold 1 Client 5] Epoch 2 time: 6.03s | train_acc=0.7189 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.7189 - loss: 0.7485 - learning_rate: 0.0010
# Epoch 3/6
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7689 - loss: 0.6290⏱️ [Fold 1 Client 5] Epoch 3 time: 6.03s | train_acc=0.7697 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - accuracy: 0.7697 - loss: 0.6151 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7698 - loss: 0.6038⏱️ [Fold 1 Client 5] Epoch 4 time: 5.66s | train_acc=0.7732 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.7732 - loss: 0.6347 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8028 - loss: 0.5445⏱️ [Fold 1 Client 5] Epoch 5 time: 5.58s | train_acc=0.8047 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.8047 - loss: 0.5375 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8173 - loss: 0.4871⏱️ [Fold 1 Client 5] Epoch 6 time: 5.88s | train_acc=0.8222 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.8222 - loss: 0.4969 - learning_rate: 0.0010
#     client 5 training time: 47.06s
#     bytes client->server: 3,254,672 bytes
# Aggregating client weights (FedAvg)...
# Evaluating global model on validation set...
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 8s 92ms/step - accuracy: 0.2550 - loss: 2.6905
# [Round 1] Val loss: 2.6905 | Val accuracy: 0.2550
# [✓] Saved checkpoint: sdg-models/federated_model_round_1.keras
#
# ========== ROUND 2/5 ==========
#   -> Client 1/5 | samples: 1143
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6747 - loss: 0.8583⏱️ [Fold 2 Client 1] Epoch 1 time: 17.40s | train_acc=0.6710 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - accuracy: 0.6710 - loss: 0.8692 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7030 - loss: 0.7384⏱️ [Fold 2 Client 1] Epoch 2 time: 5.73s | train_acc=0.7130 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.7130 - loss: 0.7196 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7406 - loss: 0.6693⏱️ [Fold 2 Client 1] Epoch 3 time: 6.16s | train_acc=0.7629 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.7629 - loss: 0.6326 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7741 - loss: 0.6840⏱️ [Fold 2 Client 1] Epoch 4 time: 5.84s | train_acc=0.7647 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.7647 - loss: 0.6305 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7445 - loss: 0.6553⏱️ [Fold 2 Client 1] Epoch 5 time: 5.66s | train_acc=0.7620 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.7620 - loss: 0.6146 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8060 - loss: 0.5281⏱️ [Fold 2 Client 1] Epoch 6 time: 5.67s | train_acc=0.8101 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.8101 - loss: 0.5345 - learning_rate: 0.0010
#     client 1 training time: 46.81s
#     bytes client->server: 3,254,672 bytes
#   -> Client 2/5 | samples: 1143
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6207 - loss: 0.9376⏱️ [Fold 2 Client 2] Epoch 1 time: 16.76s | train_acc=0.6474 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 17s 141ms/step - accuracy: 0.6474 - loss: 0.8815 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7360 - loss: 0.7144⏱️ [Fold 2 Client 2] Epoch 2 time: 5.60s | train_acc=0.7314 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.7314 - loss: 0.7111 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7593 - loss: 0.6742⏱️ [Fold 2 Client 2] Epoch 3 time: 5.64s | train_acc=0.7577 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.7577 - loss: 0.6764 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7933 - loss: 0.5564⏱️ [Fold 2 Client 2] Epoch 4 time: 5.52s | train_acc=0.7743 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.7743 - loss: 0.6020 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7710 - loss: 0.5645⏱️ [Fold 2 Client 2] Epoch 5 time: 5.88s | train_acc=0.7804 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.7804 - loss: 0.5677 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8039 - loss: 0.5009⏱️ [Fold 2 Client 2] Epoch 6 time: 5.87s | train_acc=0.7979 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.7979 - loss: 0.5230 - learning_rate: 0.0010
#     client 2 training time: 45.65s
#     bytes client->server: 3,254,672 bytes
#   -> Client 3/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.6528 - loss: 0.8979⏱️ [Fold 2 Client 3] Epoch 1 time: 17.32s | train_acc=0.6769 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.6769 - loss: 0.8298 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7240 - loss: 0.6949⏱️ [Fold 2 Client 3] Epoch 2 time: 5.69s | train_acc=0.7487 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.7487 - loss: 0.6403 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7869 - loss: 0.5683⏱️ [Fold 2 Client 3] Epoch 3 time: 5.87s | train_acc=0.7741 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.7741 - loss: 0.5889 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8108 - loss: 0.5353⏱️ [Fold 2 Client 3] Epoch 4 time: 5.75s | train_acc=0.7977 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.7977 - loss: 0.5456 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8038 - loss: 0.5168⏱️ [Fold 2 Client 3] Epoch 5 time: 5.85s | train_acc=0.8030 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.8030 - loss: 0.5316 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8402 - loss: 0.4690⏱️ [Fold 2 Client 3] Epoch 6 time: 5.91s | train_acc=0.8257 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8257 - loss: 0.4916 - learning_rate: 0.0010
#     client 3 training time: 46.73s
#     bytes client->server: 3,254,672 bytes
#   -> Client 4/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.6147 - loss: 0.9797⏱️ [Fold 2 Client 4] Epoch 1 time: 17.32s | train_acc=0.6445 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 17s 149ms/step - accuracy: 0.6445 - loss: 0.8868 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7111 - loss: 0.7546⏱️ [Fold 2 Client 4] Epoch 2 time: 5.98s | train_acc=0.7154 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - accuracy: 0.7154 - loss: 0.7394 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7516 - loss: 0.6114⏱️ [Fold 2 Client 4] Epoch 3 time: 5.89s | train_acc=0.7592 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.7592 - loss: 0.6019 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7847 - loss: 0.5874⏱️ [Fold 2 Client 4] Epoch 4 time: 5.89s | train_acc=0.7916 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.7916 - loss: 0.5720 - learning_rate: 0.0010
# Epoch 5/6
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7756 - loss: 0.5391⏱️ [Fold 2 Client 4] Epoch 5 time: 5.79s | train_acc=0.7828 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.7828 - loss: 0.5335 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8158 - loss: 0.5027⏱️ [Fold 2 Client 4] Epoch 6 time: 5.78s | train_acc=0.8179 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8179 - loss: 0.5039 - learning_rate: 0.0010
#     client 4 training time: 46.99s
#     bytes client->server: 3,254,672 bytes
#   -> Client 5/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6344 - loss: 0.9508⏱️ [Fold 2 Client 5] Epoch 1 time: 17.45s | train_acc=0.6602 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 17s 152ms/step - accuracy: 0.6602 - loss: 0.8457 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7454 - loss: 0.6841⏱️ [Fold 2 Client 5] Epoch 2 time: 6.10s | train_acc=0.7452 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.7452 - loss: 0.6697 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7792 - loss: 0.5826⏱️ [Fold 2 Client 5] Epoch 3 time: 5.74s | train_acc=0.7750 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.7750 - loss: 0.6004 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7989 - loss: 0.5342⏱️ [Fold 2 Client 5] Epoch 4 time: 5.96s | train_acc=0.8039 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8039 - loss: 0.5433 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8137 - loss: 0.5042⏱️ [Fold 2 Client 5] Epoch 5 time: 5.76s | train_acc=0.8214 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8214 - loss: 0.4948 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8187 - loss: 0.4811⏱️ [Fold 2 Client 5] Epoch 6 time: 5.86s | train_acc=0.8310 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.8310 - loss: 0.4516 - learning_rate: 0.0010
#     client 5 training time: 47.25s
#     bytes client->server: 3,254,672 bytes
# Aggregating client weights (FedAvg)...
# Evaluating global model on validation set...
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.2621 - loss: 2.2443
# [Round 2] Val loss: 2.2443 | Val accuracy: 0.2621
# [✓] Saved checkpoint: sdg-models/federated_model_round_2.keras
#
# ========== ROUND 3/5 ==========
#   -> Client 1/5 | samples: 1143
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.7540 - loss: 0.7163⏱️ [Fold 3 Client 1] Epoch 1 time: 17.15s | train_acc=0.7454 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 17s 147ms/step - accuracy: 0.7454 - loss: 0.6861 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7642 - loss: 0.5942⏱️ [Fold 3 Client 1] Epoch 2 time: 5.70s | train_acc=0.7585 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.7585 - loss: 0.6230 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7934 - loss: 0.5475⏱️ [Fold 3 Client 1] Epoch 3 time: 5.96s | train_acc=0.7892 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - accuracy: 0.7892 - loss: 0.5603 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8233 - loss: 0.4815⏱️ [Fold 3 Client 1] Epoch 4 time: 5.95s | train_acc=0.8049 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8049 - loss: 0.5275 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8340 - loss: 0.4494⏱️ [Fold 3 Client 1] Epoch 5 time: 5.83s | train_acc=0.8364 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.8364 - loss: 0.4490 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8307 - loss: 0.4652⏱️ [Fold 3 Client 1] Epoch 6 time: 5.83s | train_acc=0.8364 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8364 - loss: 0.4546 - learning_rate: 0.0010
#     client 1 training time: 46.78s
#     bytes client->server: 3,254,672 bytes
#   -> Client 2/5 | samples: 1143
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7588 - loss: 0.6859⏱️ [Fold 3 Client 2] Epoch 1 time: 17.31s | train_acc=0.7472 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 17s 148ms/step - accuracy: 0.7472 - loss: 0.6966 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7650 - loss: 0.6028⏱️ [Fold 3 Client 2] Epoch 2 time: 5.84s | train_acc=0.7734 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.7734 - loss: 0.5966 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8118 - loss: 0.5264⏱️ [Fold 3 Client 2] Epoch 3 time: 6.12s | train_acc=0.8031 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 85ms/step - accuracy: 0.8031 - loss: 0.5309 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7859 - loss: 0.5717⏱️ [Fold 3 Client 2] Epoch 4 time: 5.61s | train_acc=0.8066 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.8066 - loss: 0.5350 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8301 - loss: 0.4657⏱️ [Fold 3 Client 2] Epoch 5 time: 5.91s | train_acc=0.8198 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8198 - loss: 0.4811 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8164 - loss: 0.4894⏱️ [Fold 3 Client 2] Epoch 6 time: 5.95s | train_acc=0.8408 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8408 - loss: 0.4485 - learning_rate: 0.0010
#     client 2 training time: 47.10s
#     bytes client->server: 3,254,672 bytes
#   -> Client 3/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7980 - loss: 0.5614⏱️ [Fold 3 Client 3] Epoch 1 time: 18.16s | train_acc=0.7890 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 18s 156ms/step - accuracy: 0.7890 - loss: 0.5614 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7678 - loss: 0.5905⏱️ [Fold 3 Client 3] Epoch 2 time: 5.81s | train_acc=0.7741 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.7741 - loss: 0.5836 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8073 - loss: 0.5254⏱️ [Fold 3 Client 3] Epoch 3 time: 5.78s | train_acc=0.8135 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8135 - loss: 0.5024 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8163 - loss: 0.5111⏱️ [Fold 3 Client 3] Epoch 4 time: 6.05s | train_acc=0.8152 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.8152 - loss: 0.4950 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8090 - loss: 0.5123⏱️ [Fold 3 Client 3] Epoch 5 time: 5.89s | train_acc=0.8345 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.8345 - loss: 0.4732 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8376 - loss: 0.4280⏱️ [Fold 3 Client 3] Epoch 6 time: 5.80s | train_acc=0.8371 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8371 - loss: 0.4457 - learning_rate: 0.0010
#     client 3 training time: 47.85s
#     bytes client->server: 3,254,672 bytes
#   -> Client 4/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7225 - loss: 0.7112⏱️ [Fold 3 Client 4] Epoch 1 time: 18.50s | train_acc=0.7408 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 19s 156ms/step - accuracy: 0.7408 - loss: 0.6599 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7737 - loss: 0.6588⏱️ [Fold 3 Client 4] Epoch 2 time: 5.97s | train_acc=0.7723 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - accuracy: 0.7723 - loss: 0.6051 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7652 - loss: 0.5758⏱️ [Fold 3 Client 4] Epoch 3 time: 5.90s | train_acc=0.7898 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.7898 - loss: 0.5396 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8279 - loss: 0.4658⏱️ [Fold 3 Client 4] Epoch 4 time: 5.74s | train_acc=0.8161 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.8161 - loss: 0.4867 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8256 - loss: 0.4643⏱️ [Fold 3 Client 4] Epoch 5 time: 5.69s | train_acc=0.8249 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.8249 - loss: 0.4775 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8239 - loss: 0.4590⏱️ [Fold 3 Client 4] Epoch 6 time: 5.90s | train_acc=0.8310 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.8310 - loss: 0.4567 - learning_rate: 0.0010
#     client 4 training time: 48.09s
#     bytes client->server: 3,254,672 bytes
#   -> Client 5/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7973 - loss: 0.5693⏱️ [Fold 3 Client 5] Epoch 1 time: 18.55s | train_acc=0.7811 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 19s 159ms/step - accuracy: 0.7811 - loss: 0.6163 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.7778 - loss: 0.5796⏱️ [Fold 3 Client 5] Epoch 2 time: 5.59s | train_acc=0.7802 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.7802 - loss: 0.5691 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7935 - loss: 0.5543⏱️ [Fold 3 Client 5] Epoch 3 time: 5.95s | train_acc=0.8039 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8039 - loss: 0.5341 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8210 - loss: 0.5187⏱️ [Fold 3 Client 5] Epoch 4 time: 6.03s | train_acc=0.8257 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.8257 - loss: 0.4969 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8496 - loss: 0.4158⏱️ [Fold 3 Client 5] Epoch 5 time: 6.00s | train_acc=0.8424 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - accuracy: 0.8424 - loss: 0.4343 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8403 - loss: 0.4614⏱️ [Fold 3 Client 5] Epoch 6 time: 5.82s | train_acc=0.8450 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8450 - loss: 0.4397 - learning_rate: 0.0010
#     client 5 training time: 48.29s
#     bytes client->server: 3,254,672 bytes
# Aggregating client weights (FedAvg)...
# Evaluating global model on validation set...
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.3155 - loss: 2.0081
# [Round 3] Val loss: 2.0081 | Val accuracy: 0.3155
# [✓] Saved checkpoint: sdg-models/federated_model_round_3.keras
#
# ========== ROUND 4/5 ==========
#   -> Client 1/5 | samples: 1143
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8306 - loss: 0.5216⏱️ [Fold 4 Client 1] Epoch 1 time: 17.52s | train_acc=0.8241 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 18s 149ms/step - accuracy: 0.8241 - loss: 0.5237 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8377 - loss: 0.4571⏱️ [Fold 4 Client 1] Epoch 2 time: 5.88s | train_acc=0.8329 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8329 - loss: 0.4895 - learning_rate: 0.0010
# Epoch 3/6
# 71/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8182 - loss: 0.4783⏱️ [Fold 4 Client 1] Epoch 3 time: 5.71s | train_acc=0.8285 val_acc=None
# ...
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8513 - loss: 0.4168 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8713 - loss: 0.3854⏱️ [Fold 4 Client 2] Epoch 6 time: 5.86s | train_acc=0.8591 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.8591 - loss: 0.3986 - learning_rate: 0.0010
#     client 2 training time: 46.95s
#     bytes client->server: 3,254,672 bytes
#   -> Client 3/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8236 - loss: 0.4901⏱️ [Fold 4 Client 3] Epoch 1 time: 17.60s | train_acc=0.8310 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 18s 147ms/step - accuracy: 0.8310 - loss: 0.4665 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8200 - loss: 0.4970⏱️ [Fold 4 Client 3] Epoch 2 time: 5.92s | train_acc=0.8389 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8389 - loss: 0.4553 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8547 - loss: 0.4094⏱️ [Fold 4 Client 3] Epoch 3 time: 5.82s | train_acc=0.8398 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.8398 - loss: 0.4365 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8420 - loss: 0.4041⏱️ [Fold 4 Client 3] Epoch 4 time: 5.76s | train_acc=0.8406 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8406 - loss: 0.4164 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8638 - loss: 0.3690⏱️ [Fold 4 Client 3] Epoch 5 time: 5.73s | train_acc=0.8651 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.8651 - loss: 0.3709 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8653 - loss: 0.3799⏱️ [Fold 4 Client 3] Epoch 6 time: 5.93s | train_acc=0.8678 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8678 - loss: 0.3597 - learning_rate: 0.0010
#     client 3 training time: 47.10s
#     bytes client->server: 3,254,672 bytes
#   -> Client 4/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8156 - loss: 0.5126⏱️ [Fold 4 Client 4] Epoch 1 time: 17.97s | train_acc=0.8161 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 18s 156ms/step - accuracy: 0.8161 - loss: 0.5116 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8083 - loss: 0.5261⏱️ [Fold 4 Client 4] Epoch 2 time: 5.60s | train_acc=0.8170 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.8170 - loss: 0.5001 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8418 - loss: 0.4265⏱️ [Fold 4 Client 4] Epoch 3 time: 5.52s | train_acc=0.8380 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.8380 - loss: 0.4311 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8336 - loss: 0.4192⏱️ [Fold 4 Client 4] Epoch 4 time: 5.79s | train_acc=0.8214 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8214 - loss: 0.4610 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8509 - loss: 0.4407⏱️ [Fold 4 Client 4] Epoch 5 time: 5.59s | train_acc=0.8529 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.8529 - loss: 0.4296 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8457 - loss: 0.4129⏱️ [Fold 4 Client 4] Epoch 6 time: 5.52s | train_acc=0.8459 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.8459 - loss: 0.4298 - learning_rate: 0.0010
#     client 4 training time: 46.31s
#     bytes client->server: 3,254,672 bytes
#   -> Client 5/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8258 - loss: 0.4740⏱️ [Fold 4 Client 5] Epoch 1 time: 18.01s | train_acc=0.8205 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 18s 157ms/step - accuracy: 0.8205 - loss: 0.4926 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8657 - loss: 0.4197⏱️ [Fold 4 Client 5] Epoch 2 time: 5.81s | train_acc=0.8485 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8485 - loss: 0.4548 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8441 - loss: 0.4018⏱️ [Fold 4 Client 5] Epoch 3 time: 5.82s | train_acc=0.8398 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8398 - loss: 0.4319 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8552 - loss: 0.3857⏱️ [Fold 4 Client 5] Epoch 4 time: 5.77s | train_acc=0.8538 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8538 - loss: 0.4092 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8639 - loss: 0.4255⏱️ [Fold 4 Client 5] Epoch 5 time: 5.91s | train_acc=0.8546 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8546 - loss: 0.4220 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8489 - loss: 0.3758⏱️ [Fold 4 Client 5] Epoch 6 time: 5.92s | train_acc=0.8625 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8625 - loss: 0.3632 - learning_rate: 0.0010
#     client 5 training time: 47.55s
#     bytes client->server: 3,254,672 bytes
# Aggregating client weights (FedAvg)...
# Evaluating global model on validation set...
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.4873 - loss: 1.4214
# [Round 4] Val loss: 1.4214 | Val accuracy: 0.4873
# [✓] Saved checkpoint: sdg-models/federated_model_round_4.keras
#
# ========== ROUND 5/5 ==========
#   -> Client 1/5 | samples: 1143
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.8562 - loss: 0.4224⏱️ [Fold 5 Client 1] Epoch 1 time: 17.51s | train_acc=0.8434 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 18s 150ms/step - accuracy: 0.8434 - loss: 0.4430 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8456 - loss: 0.4163⏱️ [Fold 5 Client 1] Epoch 2 time: 6.00s | train_acc=0.8399 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - accuracy: 0.8399 - loss: 0.4304 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8622 - loss: 0.3909⏱️ [Fold 5 Client 1] Epoch 3 time: 5.74s | train_acc=0.8513 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.8513 - loss: 0.4145 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8712 - loss: 0.3785⏱️ [Fold 5 Client 1] Epoch 4 time: 5.87s | train_acc=0.8679 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.8679 - loss: 0.3894 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8699 - loss: 0.3964⏱️ [Fold 5 Client 1] Epoch 5 time: 5.78s | train_acc=0.8661 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8661 - loss: 0.3871 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8592 - loss: 0.3986⏱️ [Fold 5 Client 1] Epoch 6 time: 5.53s | train_acc=0.8653 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.8653 - loss: 0.3704 - learning_rate: 0.0010
#     client 1 training time: 46.74s
#     bytes client->server: 3,254,672 bytes
#   -> Client 2/5 | samples: 1143
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8559 - loss: 0.4665⏱️ [Fold 5 Client 2] Epoch 1 time: 16.95s | train_acc=0.8469 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 17s 142ms/step - accuracy: 0.8469 - loss: 0.4534 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8350 - loss: 0.4194⏱️ [Fold 5 Client 2] Epoch 2 time: 5.93s | train_acc=0.8425 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8425 - loss: 0.4169 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8608 - loss: 0.4056⏱️ [Fold 5 Client 2] Epoch 3 time: 6.04s | train_acc=0.8548 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.8548 - loss: 0.3817 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8630 - loss: 0.3713⏱️ [Fold 5 Client 2] Epoch 4 time: 5.92s | train_acc=0.8723 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8723 - loss: 0.3530 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8591 - loss: 0.3709⏱️ [Fold 5 Client 2] Epoch 5 time: 5.94s | train_acc=0.8556 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.8556 - loss: 0.3770 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8648 - loss: 0.3424⏱️ [Fold 5 Client 2] Epoch 6 time: 5.83s | train_acc=0.8609 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8609 - loss: 0.3592 - learning_rate: 0.0010
#     client 2 training time: 46.92s
#     bytes client->server: 3,254,672 bytes
#   -> Client 3/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.8646 - loss: 0.3858⏱️ [Fold 5 Client 3] Epoch 1 time: 17.58s | train_acc=0.8546 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 18s 151ms/step - accuracy: 0.8546 - loss: 0.3934 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8573 - loss: 0.3544⏱️ [Fold 5 Client 3] Epoch 2 time: 5.74s | train_acc=0.8643 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8643 - loss: 0.3516 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8867 - loss: 0.3202⏱️ [Fold 5 Client 3] Epoch 3 time: 5.79s | train_acc=0.8853 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8853 - loss: 0.3305 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8755 - loss: 0.3401⏱️ [Fold 5 Client 3] Epoch 4 time: 5.89s | train_acc=0.8722 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.8722 - loss: 0.3473 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8927 - loss: 0.2961⏱️ [Fold 5 Client 3] Epoch 5 time: 6.02s | train_acc=0.8897 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - accuracy: 0.8897 - loss: 0.3091 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8870 - loss: 0.2931⏱️ [Fold 5 Client 3] Epoch 6 time: 5.97s | train_acc=0.8940 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - accuracy: 0.8940 - loss: 0.2976 - learning_rate: 0.0010
#     client 3 training time: 47.35s
#     bytes client->server: 3,254,672 bytes
#   -> Client 4/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8455 - loss: 0.4008⏱️ [Fold 5 Client 4] Epoch 1 time: 17.95s | train_acc=0.8371 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 18s 156ms/step - accuracy: 0.8371 - loss: 0.4315 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8877 - loss: 0.3533⏱️ [Fold 5 Client 4] Epoch 2 time: 5.81s | train_acc=0.8722 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8722 - loss: 0.3912 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8522 - loss: 0.3882⏱️ [Fold 5 Client 4] Epoch 3 time: 5.83s | train_acc=0.8494 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.8494 - loss: 0.3928 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8740 - loss: 0.3289⏱️ [Fold 5 Client 4] Epoch 4 time: 5.52s | train_acc=0.8599 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.8599 - loss: 0.3729 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8882 - loss: 0.3245⏱️ [Fold 5 Client 4] Epoch 5 time: 5.31s | train_acc=0.8879 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.8879 - loss: 0.3320 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8725 - loss: 0.3666⏱️ [Fold 5 Client 4] Epoch 6 time: 5.83s | train_acc=0.8800 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8800 - loss: 0.3456 - learning_rate: 0.0010
#     client 4 training time: 46.56s
#     bytes client->server: 3,254,672 bytes
#   -> Client 5/5 | samples: 1142
#     bytes server->client: 3,254,672 bytes
# Epoch 1/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8496 - loss: 0.3820⏱️ [Fold 5 Client 5] Epoch 1 time: 18.03s | train_acc=0.8590 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 18s 157ms/step - accuracy: 0.8590 - loss: 0.3939 - learning_rate: 0.0010
# Epoch 2/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8543 - loss: 0.4337⏱️ [Fold 5 Client 5] Epoch 2 time: 5.70s | train_acc=0.8511 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.8511 - loss: 0.4391 - learning_rate: 0.0010
# Epoch 3/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8761 - loss: 0.3621⏱️ [Fold 5 Client 5] Epoch 3 time: 5.79s | train_acc=0.8774 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8774 - loss: 0.3642 - learning_rate: 0.0010
# Epoch 4/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9024 - loss: 0.2893⏱️ [Fold 5 Client 5] Epoch 4 time: 5.67s | train_acc=0.8897 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.8897 - loss: 0.3323 - learning_rate: 0.0010
# Epoch 5/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8852 - loss: 0.3176⏱️ [Fold 5 Client 5] Epoch 5 time: 6.29s | train_acc=0.8713 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 87ms/step - accuracy: 0.8713 - loss: 0.3372 - learning_rate: 0.0010
# Epoch 6/6
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9116 - loss: 0.2996⏱️ [Fold 5 Client 5] Epoch 6 time: 5.82s | train_acc=0.8932 val_acc=None
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 6s 80ms/step - accuracy: 0.8932 - loss: 0.3199 - learning_rate: 0.0010
#     client 5 training time: 47.63s
#     bytes client->server: 3,254,672 bytes
# Aggregating client weights (FedAvg)...
# Evaluating global model on validation set...
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.4978 - loss: 1.3477
# [Round 5] Val loss: 1.3477 | Val accuracy: 0.4978
# [✓] Saved checkpoint: sdg-models/federated_model_round_5.keras
# [LOG] Saved epoch timing to: sdg-logs/federated_epoch_times.csv
# [LOG] Saved communication bytes to: sdg-logs/comm_bytes_per_round.csv
# [LOG] Saved round summary to: sdg-logs/federated_training_log.csv
#
# ========== FEDERATED TRAINING COMPLETED ==========
# Saved: training_history.png
#
# ======================================================================
# MODEL EVALUATION ON TEST SET
# ======================================================================
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 9s 92ms/step
# Test Accuracy: 0.7918
#               precision    recall  f1-score   support
#
#       glioma     0.6930    0.9633    0.8061       300
#   meningioma     0.8810    0.2418    0.3795       306
#      notumor     0.8620    0.9407    0.8996       405
#    pituitary     0.7989    0.9800    0.8802       300
#
#     accuracy                         0.7918      1311
#    macro avg     0.8087    0.7815    0.7414      1311
# weighted avg     0.8133    0.7918    0.7524      1311
# Saved: confusion_matrix.png
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved: performance_metrics.png
# Saved: federated_learning_results.json
# Saved model: federated_brain_tumor_model.h5
# Saved model: federated_brain_tumor_model.keras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from matplotlib.ticker import FuncFormatter

sns.set(style="whitegrid", font_scale=1.2)
plt.rcParams["figure.figsize"] = (10, 6)

# %%
epoch_df = pd.read_csv("sdg-logs/federated_epoch_times.csv")
round_df = pd.read_csv("sdg-logs/federated_training_log.csv")
comm_df = pd.read_csv("sdg-logs/comm_bytes_per_round.csv")

print("Epoch Data:", epoch_df.shape)
print("Round Data:", round_df.shape)
print("Comm Data:", comm_df.shape)
# Out:
# Epoch Data: (150, 9)
# Round Data: (5, 5)
# Comm Data: (25, 4)

# %%
fig, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(round_df['Round'], round_df['ValAcc'], color='#007acc', marker='o', lw=3, label='Validation Accuracy')
ax2 = ax1.twinx()
ax2.plot(round_df['Round'], round_df['ValLoss'], color='#ff4d4d', marker='s', lw=3, label='Validation Loss')

ax1.set_xlabel("Federated Rounds", fontsize=13)
ax1.set_ylabel("Validation Accuracy", color='#007acc')
ax2.set_ylabel("Validation Loss", color='#ff4d4d')
ax1.set_title("Federated CNN Performance over Rounds", fontsize=15, weight='bold')

ax1.grid(True, alpha=0.3)
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
avg_epoch_time = epoch_df.groupby(['Client'])['TimeSec'].mean().reset_index()
sns.barplot(x='Client', y='TimeSec', data=avg_epoch_time, palette='coolwarm')
plt.title("Average Epoch Time per Client", fontsize=15, weight='bold')
plt.xlabel("Client ID")
plt.ylabel("Avg Time (seconds)")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_65299/2944798485.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Client', y='TimeSec', data=avg_epoch_time, palette='coolwarm')

# %%
fig, ax1 = plt.subplots(figsize=(10,6))
ax1.bar(round_df['Round'], round_df['RoundTimeSec'], color='#ffb347', alpha=0.7, label='Round Duration (s)')
ax2 = ax1.twinx()
ax2.plot(round_df['Round'], round_df['Total_Comm_Bytes'] / 1e6, color='#007acc', marker='o', lw=3, label='Communication (MB)')

ax1.set_xlabel("Round")
ax1.set_ylabel("Duration (sec)", color='#ff9933')
ax2.set_ylabel("Communication (MB)", color='#007acc')
plt.title("Round Duration vs Communication Bytes", fontsize=15, weight='bold')
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
pivot_comm = comm_df.pivot_table(index='Client', columns='Round',
                                 values=['Bytes_Server_to_Client','Bytes_Client_to_Server'], aggfunc='sum')
sns.heatmap(pivot_comm['Bytes_Server_to_Client'] / 1e6, cmap='YlGnBu', annot=True, fmt=".2f")
plt.title("Server → Client Communication (MB)", fontsize=14, weight='bold')
plt.ylabel("Client ID")
plt.xlabel("Round")
plt.tight_layout()
plt.show()

sns.heatmap(pivot_comm['Bytes_Client_to_Server'] / 1e6, cmap='RdPu', annot=True, fmt=".2f")
plt.title("Client → Server Communication (MB)", fontsize=14, weight='bold')
plt.ylabel("Client ID")
plt.xlabel("Round")
plt.tight_layout()
plt.show()

# %%
sns.lineplot(data=epoch_df, x='Epoch', y='TrainAcc', hue='Client', palette='tab10', lw=2.5)
plt.title("Client-wise Training Accuracy per Epoch", fontsize=15, weight='bold')
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.tight_layout()
plt.show()

# %%
corr = round_df[['ValAcc', 'ValLoss', 'RoundTimeSec', 'Total_Comm_Bytes']].corr()
sns.heatmap(corr, annot=True, cmap='viridis', fmt=".2f", cbar=True)
plt.title("Correlation between Round Metrics", fontsize=15, weight='bold')
plt.tight_layout()
plt.show()

# %%
fig = px.scatter_3d(round_df, x='Round', y='ValAcc', z='RoundTimeSec',
                    size='Total_Comm_Bytes', color='ValLoss',
                    color_continuous_scale='plasma',
                    title="Federated Learning: Accuracy vs Time vs Communication",
                    labels={'ValAcc':'Validation Accuracy', 'RoundTimeSec':'Time (s)', 'Total_Comm_Bytes':'Comm Bytes'})
fig.update_traces(marker=dict(opacity=0.8, line=dict(width=1)))
fig.show()

# %%
import os
os.makedirs("visuals", exist_ok=True)
for i, f in enumerate(plt.get_fignums(), 1):
    plt.figure(f)
    plt.savefig(f"visuals/figure_{i}.png", dpi=300, bbox_inches='tight')
print("✅ All figures saved in /visuals folder.")
# Out:
# ✅ All figures saved in /visuals folder.

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=epoch_df, x='Epoch', y='TrainAcc', hue='Client', marker='o', lw=2.5, palette='tab10')
plt.title("Client-wise Training Accuracy per Epoch", fontsize=15, weight='bold')
plt.xlabel("Epoch")
plt.ylabel("Training Accuracy")
plt.legend(title='Client', loc='lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=epoch_df, x='Epoch', y='TrainLoss', hue='Client', lw=2.5, palette='coolwarm')
plt.title("Training Loss per Epoch across Clients", fontsize=15, weight='bold')
plt.xlabel("Epoch")
plt.ylabel("Training Loss")
plt.legend(title='Client', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=epoch_df, x='Epoch', y='TimeSec', hue='Client', lw=2.5, marker='o', palette='plasma')
plt.title("Per-Epoch Training Time per Client", fontsize=15, weight='bold')
plt.xlabel("Epoch")
plt.ylabel("Time (seconds)")
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
avg_acc = epoch_df.groupby("Client")['TrainAcc'].mean().reset_index()
sns.barplot(x="Client", y="TrainAcc", data=avg_acc, palette="crest")
plt.title("Average Training Accuracy per Client", fontsize=15, weight='bold')
plt.ylabel("Mean Accuracy")
plt.xlabel("Client ID")
for index, row in avg_acc.iterrows():
    plt.text(index, row.TrainAcc + 0.01, f"{row.TrainAcc:.2f}", ha='center', fontsize=10, weight='bold')
plt.ylim(0.7, 1.0)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_65299/4071055344.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=epoch_df, x="Client", y="LR", palette="mako")
plt.title("Learning Rate Distribution per Client", fontsize=15, weight='bold')
plt.xlabel("Client")
plt.ylabel("Learning Rate")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_65299/3212089915.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=epoch_df, x='TimeSec', y='TrainAcc', hue='Client', size='Epoch', sizes=(20, 200), palette='viridis', alpha=0.8)
plt.title("Accuracy vs Training Time (Efficiency Curve)", fontsize=15, weight='bold')
plt.xlabel("Training Time (s)")
plt.ylabel("Training Accuracy")
plt.legend(title="Client / Epoch")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(data=epoch_df, x='TrainLoss', y='TrainAcc', hue='Client', marker='o', lw=2, palette='coolwarm')
plt.title("Training Trajectories: Loss vs Accuracy", fontsize=15, weight='bold')
plt.xlabel("Training Loss")
plt.ylabel("Training Accuracy")
plt.tight_layout()
plt.show()

# %%
import plotly.graph_objects as go

client_summary = epoch_df.groupby('Client').agg({
    'TrainAcc':'mean',
    'TrainLoss':'mean',
    'TimeSec':'mean'
}).reset_index()

# normalize metrics 0-1
for col in ['TrainAcc','TrainLoss','TimeSec']:
    client_summary[col] = (client_summary[col] - client_summary[col].min()) / (client_summary[col].max() - client_summary[col].min())

categories = ['TrainAcc', 'TrainLoss', 'TimeSec']
fig = go.Figure()
for i, row in client_summary.iterrows():
    fig.add_trace(go.Scatterpolar(
        r=row[categories].tolist(),
        theta=categories,
        fill='toself',
        name=f'Client {int(row.Client)}'
    ))

fig.update_layout(
    polar=dict(radialaxis=dict(visible=True, range=[0,1])),
    title="Client Performance Radar (Normalized Metrics)"
)
fig.show()

# %%
sns.boxplot(data=epoch_df, x='Client', y='TimeSec', palette='ch:s=.25,rot=-.25')
plt.title("Epoch Time Distribution per Client", fontsize=15, weight='bold')
plt.xlabel("Client ID")
plt.ylabel("Epoch Duration (s)")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_65299/697950579.py:1: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
cum_time = epoch_df.groupby('Client')['TimeSec'].sum().reset_index()
sns.barplot(x='Client', y='TimeSec', data=cum_time, palette='rocket')
plt.title("Cumulative Training Time per Client", fontsize=15, weight='bold')
plt.xlabel("Client ID")
plt.ylabel("Total Time (s)")
for index, row in cum_time.iterrows():
    plt.text(index, row.TimeSec + 1, f"{row.TimeSec:.1f}", ha='center', fontsize=10, weight='bold')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_65299/1902478155.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
